# %%
# 傳入資料: Lewis API那邊傳給我使用者偏好 (JSON) ，假設台南市 3天2夜
pref = {
    "county": "台南市",
    "dates": 3,
    "departure_date": "2023-07-24",
    "return_date": "2023-07-26",

    "hotel_level": 5,
    "food_level": 5,
    "viewpoint_level": 5,

    "hotel_like_tag": ["民宿", ],
    "hotel_price_tag": 10000,
    "hotel_other_tag": ["SPA", "停車場"],

    "food_taste_tag": ["燒烤", "日式", ],
    "food_price_tag": 2,
    "food_other_tag": ["親子餐廳"],

    "viewpoint_other_tag": ["戶外活動"],
    "transportation": 1,
}

# %%
# 撈資料庫: 先用excel。excel是我從DB撈出來有處理過一些欄位。最後再一次請資料組的人幫忙處理DB的部分，若要看我洗了什麼請詳 df_清洗.ipynb)
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from shapely.geometry import Point
from geopy.distance import geodesic
import warnings
warnings.filterwarnings("ignore")
import geopandas as gpd


df_viewpoint = pd.read_excel("df_viewpoint.xlsx")
df_viewpoint = df_viewpoint[df_viewpoint["city"] == pref['county']]
df_viewpoint = gpd.GeoDataFrame(df_viewpoint, crs="EPSG:4326", geometry=[Point(lnglat) for lnglat in zip(df_viewpoint['lng'], df_viewpoint['lat'])])

df_food = pd.read_excel("df_food.xlsx")
df_food = df_food[df_food["city"] == pref['county']]
df_food = gpd.GeoDataFrame(df_food, crs="EPSG:4326", geometry=[Point(lnglat) for lnglat in zip(df_food['lng'], df_food['lat'])])

df_hotel = pd.read_excel("df_hotel.xlsx")
df_hotel = df_hotel[df_hotel["city"] == pref['county']]
df_hotel = gpd.GeoDataFrame(df_hotel, crs="EPSG:4326", geometry=[Point(lnglat) for lnglat in zip(df_hotel['lng'], df_hotel['lat'])])

# %%
#  給分數: 對 hotel food viewpoint 三張表 進行各項評分，並計算出總分(overall_score)。評分是依據使用者的偏好(pref)來進行。
from my_score import calculate_price_score, calculate_price_score_2, calculate_tag_score

# 給Hotel分數
df_hotel['like_score'] = calculate_tag_score_2(df_hotel['keyword'], pref["hotel_like_tag"])
df_hotel['price_score'] = calculate_hotel_score(df_hotel['lower_price'], df_hotel['ceiling_price'], pref['hotel_price_tag'])
df_hotel['other_score'] = calculate_tag_score_2(df_hotel['tag'], pref["hotel_other_tag"])

# 計算Hotel加權平均分數 
weights = pd.Series([0.4, 0.3, 0.3])
df_hotel['overall_score'] = np.average(df_hotel[['like_score', 'price_score', 'other_score']], axis=1, weights=weights)

# 給Food分數
df_food['taste_score'] = calculate_tag_score_2(df_food['tag'], pref["food_taste_tag"])
df_food['price_score'] = calculate_price_score_3(df_food['price_level'], pref['food_price_tag'])
df_food['other_score'] = calculate_tag_score_2(df_food['rest_tag'], pref["food_other_tag"])

# 計算Food加權平均分數 
weights = pd.Series([0.4, 0.3, 0.3])
df_food['overall_score'] = np.average(df_food[['taste_score', 'price_score', 'other_score']], axis=1, weights=weights)


# 給ViewPoint分數
df_viewpoint['other_score'] = 100
df_viewpoint['transportation_score'] = 100

# 計算ViewPoint加權平均分數 
weights = pd.Series([0.4, 0.6])
df_viewpoint['overall_score'] = np.average(df_viewpoint[['other_score', 'transportation_score']], axis=1, weights=weights)

# %%
# concat 三張表 for next step
df_food['source']='food'
df_viewpoint['source']='viewpoint'
df_hotel['source']='hotel'
concat_df = pd.concat([df_food, df_viewpoint, df_hotel])

# %%
# 分出群集: 用經緯度 將所有的地點進行分群(clusters)，並畫 map1 以檢視"所有的"clusters分布的狀況。(地圖僅做檢查用 最後要拉掉)
import geopandas as gpd
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import haversine_distances
from math import radians
import random
import folium
from folium.plugins import MarkerCluster

geo_df = pd.concat([df_food, df_viewpoint, df_hotel])

# 将经纬度转换为弧度
geo_df['lat_rad'] = geo_df['lat'].apply(radians)
geo_df['lng_rad'] = geo_df['lng'].apply(radians)

# 计算距离矩阵
haversine_matrix = haversine_distances(
    geo_df[['lat_rad', 'lng_rad']].values,
    geo_df[['lat_rad', 'lng_rad']].values
) * 6371000.0  # 6371000.0 is Earth's radius in meters

# 运行DBSCAN进行聚类
dbscan = DBSCAN(eps=2000, min_samples=3, metric='precomputed')
geo_df['cluster'] = dbscan.fit_predict(haversine_matrix)

# 分析聚类结果
num_clusters = len(set(geo_df['cluster'])) - (1 if -1 in geo_df['cluster'] else 0)
print(f"Number of clusters: {num_clusters}")

# 创建地图1：显示所有地点的地图
m1 = folium.Map(location=[geo_df['lat'].mean(), geo_df['lng'].mean()], zoom_start=12)

# 添加 MarkerCluster 层
marker_cluster1 = MarkerCluster().add_to(m1)

# 在地图上添加地点
for idx, row in geo_df.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        popup=row['name'],
        icon=None  # 使用默认图标
    ).add_to(marker_cluster1)

# 保存地图1为HTML文件 (或者 display)
m1.save("map1_all_clusters.html")
# display(m1)
# Out:
# Number of clusters: 45

# %%
# 挑選群集: 旅遊天數N天則挑最大的 N 個 clusters，並畫 map2 以檢視"所挑選的"clusters分布的狀況。(地圖僅做檢查用 最後要拉掉)
cluster_sizes = geo_df['cluster'].value_counts()

# 打印所有群集的大小和信息
print("Cluster Sizes and Information:")
for cluster_id, size in cluster_sizes.items():
    cluster_points = geo_df[geo_df['cluster'] == cluster_id]
    avg_score = cluster_points['overall_score'].mean()
    
    print(f"Cluster {cluster_id}:")
    print(f" - Size: {size} points")
    print(f" - Average Overall Score: {avg_score:.2f}")
    print(f" - Points:")
    for idx, row in cluster_points.iterrows():
        print(f"   - {row['name']} (Lat: {row['lat']}, Lng: {row['lng']}, Overall Score: {row['overall_score']})")
    print("")
    
# 找出最大的 N 个群集 (N 用旅遊天數決定)
n = pref['dates']
cluster_sizes = geo_df['cluster'].value_counts()
largest_clusters = cluster_sizes.nlargest(n).index


# 创建地图2：显示最大3个群集的地点
m2 = folium.Map(location=[geo_df['lat'].mean(), geo_df['lng'].mean()], zoom_start=12)

# 添加 MarkerCluster 层
marker_cluster2 = MarkerCluster().add_to(m2)

# 在地图上添加最大3个群集的地点
for cluster_id in largest_clusters:
    cluster_points = geo_df[geo_df['cluster'] == cluster_id]
    for idx, row in cluster_points.iterrows():
        folium.Marker(
            location=[row['lat'], row['lng']],
            popup=row['name'],
            icon=None  # 使用默认图标
        ).add_to(marker_cluster2)

# 保存地图2为HTML文件 (或者 display)
m2.save("map2.html")
# display(m2)
# Out:
# Cluster Sizes and Information:
# Cluster 0:
#  - Size: 1915 points
#  - Average Overall Score: 50.18
#  - Points:
#    - 和牛涮 台南中華西店 (Lat: 22.9935, Lng: 120.187, Overall Score: 44.0)
#    - 小豪洲沙茶爐中正總店 (Lat: 22.9932, Lng: 120.2, Overall Score: 44.0)
#    - 輕井澤鍋物 台南店 (Lat: 22.9869, Lng: 120.186, Overall Score: 44.0)
#    - 阿裕牛肉涮涮鍋一崑崙店 (Lat: 22.9404, Lng: 120.261, Overall Score: 38.0)
#    - 是吉祥精緻火鍋館 (Lat: 22.978, Lng: 120.186, Overall Score: 44.0)
#    - 隱鍋 台南海安店 (Lat: 23.0193, Lng: 120.2, Overall Score: 44.0)
#    - 饕公麻辣燙 (Lat: 22.9904, Lng: 120.199, Overall Score: 44.0)
#    - 野村日式燒肉 永大店 (Lat: 23.0181, Lng: 120.263, Overall Score: 26.0)
#    - 有你真好 火鍋沙龍 (Lat: 22.9958, Lng: 120.195, Overall Score: 38.0)
#    - 春囍打邊爐台南店 (Lat: 22.979, Lng: 120.228, Overall Score: 32.0)
#    - LA時尚川菜│永康店 (Lat: 23.0211, Lng: 120.261, Overall Score: 38.0)
#    - 三大牛肉火鍋 (Lat: 23.0034, Lng: 120.26, Overall Score: 32.0)
#    - 老廣粵 花雕雞創意坊 (Lat: 22.9884, Lng: 120.178, Overall Score: 26.0)
#    - 一燒十味昭和園安平店 (Lat: 22.9892, Lng: 120.171, Overall Score: 26.0)
#    - 小董牛肉湯爐 (Lat: 23.0003, Lng: 120.227, Overall Score: 44.0)
#    - 饗麻饗辣 台南永華旗艦店 (Lat: 22.9889, Lng: 120.186, Overall Score: 38.0)
#    - 健康燒肉屋 貴一郎 (Lat: 23.0035, Lng: 120.219, Overall Score: 38.0)
#    - 劉家莊牛肉爐 (Lat: 23.0316, Lng: 120.253, Overall Score: 44.0)
#    - 古城豆花庄（老店） (Lat: 23.0126, Lng: 120.231, Overall Score: 44.0)
#    - 咚豬咚豬。韓國烤肉吃到飽（台南東區中華門市） (Lat: 22.9744, Lng: 120.224, Overall Score: 44.0)
#    - 永林綜合料理 Yonlin Restaurant (Lat: 23.0025, Lng: 120.226, Overall Score: 32.0)
#    - 一番地壽喜燒-台南安平店 (Lat: 22.9891, Lng: 120.185, Overall Score: 38.0)
#    - 福相麻辣香鍋 中華店 (Lat: 22.9806, Lng: 120.229, Overall Score: 26.0)
#    - 悠然居生活茶坊 (Lat: 23.0094, Lng: 120.206, Overall Score: 44.0)
#    - 牧鍋頂級熟成牛鍋物 (Lat: 22.9903, Lng: 120.245, Overall Score: 26.0)
#    - 新馬辣經典麻辣鍋-台南南紡店 (Lat: 22.9915, Lng: 120.233, Overall Score: 32.0)
#    - 唐家泡菜館 (Lat: 22.985, Lng: 120.225, Overall Score: 44.0)
#    - 肉多多火鍋-台南東寧店 (Lat: 22.9891, Lng: 120.231, Overall Score: 38.0)
#    - 馨味胡椒白菜雞 (Lat: 23.016, Lng: 120.211, Overall Score: 44.0)
#    - 海底撈火鍋 台南Focus店 (Lat: 22.9956, Lng: 120.21, Overall Score: 26.0)
#    - 饗宴麻辣火鍋 (Lat: 22.9868, Lng: 120.233, Overall Score: 38.0)
#    - 這一小鍋 台南新光中山店 (Lat: 22.9955, Lng: 120.21, Overall Score: 44.0)
#    - 築間幸福鍋物 台南府前一店 (Lat: 22.9955, Lng: 120.185, Overall Score: 44.0)
#    - 珍好味臭臭鍋 (Lat: 23.017, Lng: 120.238, Overall Score: 44.0)
#    - Walking Su 藥膳麻油雞 (Lat: 22.9956, Lng: 120.227, Overall Score: 44.0)
#    - 五鮮級鍋物專賣 永康大灣店 (Lat: 22.999, Lng: 120.252, Overall Score: 44.0)
#    - 鐵木匠複合式餐廳 (Lat: 23.0205, Lng: 120.263, Overall Score: 44.0)
#    - 養鍋 Yang Guo 石頭涮涮鍋 (台南文化店) (Lat: 22.9743, Lng: 120.223, Overall Score: 38.0)
#    - 海底撈火鍋台南南紡店 (Lat: 22.9924, Lng: 120.233, Overall Score: 38.0)
#    - 寶TAKARA日式涮涮鍋 (Lat: 22.9906, Lng: 120.176, Overall Score: 26.0)
#    - 築間幸福鍋物 台南成大店 (Lat: 22.9954, Lng: 120.218, Overall Score: 38.0)
#    - Mo-Mo-Paradise 台南南紡牧場 (Lat: 22.9901, Lng: 120.233, Overall Score: 38.0)
#    - 這一鍋 台南新光殿 (Lat: 22.9873, Lng: 120.199, Overall Score: 26.0)
#    - 輝哥本土牛肉爐 (Lat: 22.9701, Lng: 120.267, Overall Score: 44.0)
#    - 台南火鍋-老城門·台南火鍋推薦/台南必吃火鍋/台南安平美食 (Lat: 22.9891, Lng: 120.17, Overall Score: 44.0)
#    - 泰妃餐館 Tai Fei 泰式火鍋餐酒館 (Lat: 22.983, Lng: 120.197, Overall Score: 44.0)
#    - 小赤佬干鍋 忠義店 (Lat: 22.9947, Lng: 120.203, Overall Score: 44.0)
#    - 五鮮級鍋物專賣 台南北門店 (Lat: 23.0037, Lng: 120.214, Overall Score: 44.0)
#    - 新馬辣經典麻辣鍋-台南西門店 (Lat: 22.9867, Lng: 120.199, Overall Score: 32.0)
#    - 助仔牛肉湯 (Lat: 22.9989, Lng: 120.169, Overall Score: 44.0)
#    - 台南阿官火鍋專家府前店 (Lat: 22.9935, Lng: 120.184, Overall Score: 44.0)
#    - 永康老牌石頭火鍋 (Lat: 23.0162, Lng: 120.258, Overall Score: 44.0)
#    - くら寿司 藏壽司 台南FOCUS店 (Lat: 22.9956, Lng: 120.21, Overall Score: 44.0)
#    - 藍晒圖文創園區 (Lat: 22.9871, Lng: 120.197, Overall Score: 38.0)
#    - 碳佐麻里精品燒肉 台南府前店 (Lat: 22.9935, Lng: 120.184, Overall Score: 32.0)
#    - 饗食天堂台南西門店 (Lat: 22.9869, Lng: 120.198, Overall Score: 26.0)
#    - 熨斗目花珈琲 珈哩WUDAO cafe (Lat: 22.9957, Lng: 120.201, Overall Score: 38.0)
#    - 台南南紡威秀影城 (Lat: 22.9913, Lng: 120.233, Overall Score: 38.0)
#    - 冰ㄉ• かき氷 (Lat: 22.9811, Lng: 120.223, Overall Score: 44.0)
#    - Chun純薏仁。甜點。 (Lat: 22.9908, Lng: 120.199, Overall Score: 44.0)
#    - 野村燒肉-台南康樂店 (Lat: 22.993, Lng: 120.195, Overall Score: 32.0)
#    - 赤崁棺材板 (Lat: 22.9924, Lng: 120.196, Overall Score: 44.0)
#    - 老厝1933 (Lat: 22.9904, Lng: 120.21, Overall Score: 44.0)
#    - 山根壽司 (Lat: 22.9969, Lng: 120.202, Overall Score: 44.0)
#    - 鰻丼作 (Lat: 22.9907, Lng: 120.2, Overall Score: 44.0)
#    - 醇涎坊古早味鍋燒意麵 (Lat: 22.9902, Lng: 120.196, Overall Score: 44.0)
#    - 肉丼丼食專門店 (Lat: 22.9905, Lng: 120.224, Overall Score: 44.0)
#    - 東加和漢日式創作料理｜台南 壽喜鴛鴦火鍋吃到飽｜團體親子聚會自助餐廳 (Lat: 22.9891, Lng: 120.185, Overall Score: 32.0)
#    - 聚樂炭燒居食屋 居酒屋 日本料理 餐廳 燒烤 串燒 海鮮 包廂 尾牙 春酒 100人用餐 (Lat: 22.9975, Lng: 120.188, Overall Score: 44.0)
#    - 纓風壽司（永康店） (Lat: 23.0289, Lng: 120.252, Overall Score: 44.0)
#    - 府城騷烤家 (Lat: 22.9945, Lng: 120.213, Overall Score: 38.0)
#    - Mr.meat炭烤牛排丼飯 國華店 (Lat: 22.988, Lng: 120.196, Overall Score: 44.0)
#    - 衛屋茶事Sputnik Lab (Lat: 22.9995, Lng: 120.212, Overall Score: 44.0)
#    - 采田壽司 (Lat: 23.0128, Lng: 120.246, Overall Score: 44.0)
#    - 大丸家手作炸雞甜甜圈 (Lat: 22.9871, Lng: 120.2, Overall Score: 44.0)
#    - 八峰亭 (Lat: 22.9896, Lng: 120.21, Overall Score: 44.0)
#    - 燒肉同話 台南新光店 (Lat: 22.9873, Lng: 120.199, Overall Score: 26.0)
#    - 鮨次郎壽司專賣 (Lat: 22.9875, Lng: 120.231, Overall Score: 44.0)
#    - 藏金_安平貓小巴 (Lat: 22.9947, Lng: 120.221, Overall Score: 44.0)
#    - Kokoni Kakigori (Lat: 22.9981, Lng: 120.201, Overall Score: 44.0)
#    - 炙丼家 (Lat: 22.9883, Lng: 120.233, Overall Score: 44.0)
#    - 纓風壽司 (公園店)每週二、三店休 (Lat: 22.9953, Lng: 120.205, Overall Score: 44.0)
#    - 上原UEHARA日式料理 (Lat: 22.9927, Lng: 120.182, Overall Score: 26.0)
#    - 築地專賣壽司 (Lat: 22.9828, Lng: 120.222, Overall Score: 38.0)
#    - スシロー壽司郎 台南安平店 (Lat: 22.993, Lng: 120.187, Overall Score: 44.0)
#    - 豆弄 とろ (Lat: 22.9826, Lng: 120.209, Overall Score: 44.0)
#    - Nest居酒屋 de 三十八番 (Lat: 22.9981, Lng: 120.202, Overall Score: 44.0)
#    - 大河屋 居酒屋-台南新天地西門店 (Lat: 22.9868, Lng: 120.198, Overall Score: 38.0)
#    - CaffeBene海安藝文門市 (Lat: 22.9959, Lng: 120.197, Overall Score: 44.0)
#    - 淳鳩一夫拉麵 (Lat: 22.9957, Lng: 120.201, Overall Score: 44.0)
#    - 芊湶鰻丼 壽司 每週二、三店休 (Lat: 22.9883, Lng: 120.187, Overall Score: 44.0)
#    - 水恃 日式料理 (Lat: 22.9944, Lng: 120.231, Overall Score: 44.0)
#    - 趣活藍晒圖(好好吃飯) (Lat: 22.9868, Lng: 120.197, Overall Score: 44.0)
#    - 兵衛丼 (Lat: 22.995, Lng: 120.202, Overall Score: 38.0)
#    - 魚小璐和洋廚房 (Lat: 23.0219, Lng: 120.233, Overall Score: 44.0)
#    - スシロー壽司郎 台南南紡店 (Lat: 22.9915, Lng: 120.233, Overall Score: 26.0)
#    - 愛烤愛對囉 台南店 (Lat: 22.9814, Lng: 120.206, Overall Score: 32.0)
#    - 燒究餐飲集團-台南燒肉推薦｜焼肉ショジョ Yakiniku SHOJO 台南安平店 (Lat: 22.9926, Lng: 120.183, Overall Score: 44.0)
#    - 好好吃肉韓式烤肉吃到飽-台南民族店 (Lat: 22.9946, Lng: 120.21, Overall Score: 38.0)
#    - 尖叫 SCREAM 精緻炭火燒肉 台南旗艦店 (Lat: 22.9901, Lng: 120.234, Overall Score: 26.0)
#    - 㕩肉舖Pankoko X 燒肉專門店 (Lat: 22.9959, Lng: 120.203, Overall Score: 26.0)
#    - 東大門韓國烤肉料理 (Lat: 22.9891, Lng: 120.184, Overall Score: 32.0)
#    - 好客燒烤-台南Focus店 (Lat: 22.9956, Lng: 120.21, Overall Score: 26.0)
#    - 田季發爺燒肉 台南中華店 (Lat: 22.9862, Lng: 120.233, Overall Score: 26.0)
#    - 肉吧·RouBar x 燒肉專門店 (Lat: 22.9956, Lng: 120.193, Overall Score: 38.0)
#    - ABC Burger (Lat: 22.992, Lng: 120.195, Overall Score: 44.0)
#    - 蚵男 生蠔 海物 燒烤 (Lat: 23.019, Lng: 120.2, Overall Score: 26.0)
#    - 青青燒肉 (Lat: 22.9826, Lng: 120.23, Overall Score: 38.0)
#    - 肉次方 台南府前店 (Lat: 22.9929, Lng: 120.186, Overall Score: 26.0)
#    - 壹心燒肉 台南安平店 (Lat: 22.9954, Lng: 120.186, Overall Score: 26.0)
#    - 小南人烤肉廚房 (Lat: 22.9897, Lng: 120.197, Overall Score: 44.0)
#    - 肕 燒肉.酒肆 (Lat: 22.9888, Lng: 120.208, Overall Score: 26.0)
#    - 秋收炭烤 (Lat: 22.9887, Lng: 120.21, Overall Score: 44.0)
#    - 乾杯燒肉居酒屋 台南成功店 (Lat: 22.9963, Lng: 120.214, Overall Score: 26.0)
#    - 魚老鐵烤魚（台南創始店） (Lat: 22.9975, Lng: 120.205, Overall Score: 38.0)
#    - 鯨吞燒 串燒酒場-總本店 (Lat: 22.9996, Lng: 120.198, Overall Score: 38.0)
#    - 泰式幽靈串燒-保安店 (Lat: 22.9913, Lng: 120.191, Overall Score: 44.0)
#    - 疆疆串燒烤肉專賣店 (Lat: 22.9903, Lng: 120.197, Overall Score: 44.0)
#    - 皋月當代日式料理 (Lat: 22.9908, Lng: 120.206, Overall Score: 44.0)
#    - 昭和九十八大眾食堂 (Lat: 23.0098, Lng: 120.214, Overall Score: 44.0)
#    - 原佃燒烤(南紡) (Lat: 22.99, Lng: 120.236, Overall Score: 44.0)
#    - おやじ歐野基串焼き屋台 (Lat: 22.998, Lng: 120.205, Overall Score: 44.0)
#    - 泰式幽靈串燒-永康店 (Lat: 23.0166, Lng: 120.236, Overall Score: 44.0)
#    - 麻坡韓國炭火燒肉 (Lat: 22.9927, Lng: 120.183, Overall Score: 38.0)
#    - 進福大灣花生糖-赤崁店 (Lat: 22.9967, Lng: 120.203, Overall Score: 44.0)
#    - 大股 熟成燒肉專門-台南永華店 (Lat: 22.9886, Lng: 120.188, Overall Score: 26.0)
#    - 銀樂日式手創料理 (Lat: 22.9879, Lng: 120.232, Overall Score: 38.0)
#    - 獨領瘋燒-永康特色美食 (Lat: 23.0121, Lng: 120.232, Overall Score: 44.0)
#    - 焦糖楓串燒連鎖第一品牌/台南海安店(內用.外帶) (Lat: 22.9917, Lng: 120.196, Overall Score: 44.0)
#    - 碳味亭燒烤小炒 (Lat: 22.9838, Lng: 120.211, Overall Score: 38.0)
#    - 芙蓉鳥燒 (Lat: 22.9981, Lng: 120.202, Overall Score: 26.0)
#    - おかんとO KAN Do 大眾酒場 (Lat: 22.9903, Lng: 120.197, Overall Score: 44.0)
#    - 燒肉工廠 台南旗艦店 (Lat: 22.9933, Lng: 120.234, Overall Score: 32.0)
#    - 念水町日式再生酒場 (Lat: 22.994, Lng: 120.196, Overall Score: 44.0)
#    - 燒肉難民營（店休請看粉絲專頁） (Lat: 23.0032, Lng: 120.205, Overall Score: 44.0)
#    - The BBQ House 台南府前店 (Lat: 22.9934, Lng: 120.184, Overall Score: 44.0)
#    - 卑南胡同燒烤 (Lat: 22.9945, Lng: 120.229, Overall Score: 44.0)
#    - 豐燒串燒關東煮 (Lat: 22.9913, Lng: 120.21, Overall Score: 44.0)
#    - 945夯海鮮燒烤 (Lat: 22.9977, Lng: 120.258, Overall Score: 44.0)
#    - 初云燒肉 (Lat: 22.9897, Lng: 120.172, Overall Score: 32.0)
#    - 路邊烤肉wildbbq 台南 (Lat: 23.0037, Lng: 120.215, Overall Score: 44.0)
#    - 無邪燒肉 (Lat: 22.9963, Lng: 120.217, Overall Score: 38.0)
#    - 台南晶英酒店 (Lat: 22.9873, Lng: 120.199, Overall Score: 32.0)
#    - 台南晶英酒店—ROBIN’S 牛排館 (Lat: 22.9876, Lng: 120.199, Overall Score: 44.0)
#    - 漢來海港餐廳 台南店 (Lat: 22.9915, Lng: 120.233, Overall Score: 32.0)
#    - 台南晶英酒店－晶英軒 (Lat: 22.9872, Lng: 120.2, Overall Score: 26.0)
#    - 台南遠東香格里拉 (Lat: 22.9967, Lng: 120.214, Overall Score: 26.0)
#    - zero zero 拆車夢工廠 - 觀光工廠 & 餐酒館 (Lat: 22.999, Lng: 120.249, Overall Score: 44.0)
#    - 天馬星空餐酒館 Bistro Tian Ma Xing Kong (Lat: 22.996, Lng: 120.184, Overall Score: 32.0)
#    - 元素餐廳 (Lat: 22.9993, Lng: 120.149, Overall Score: 38.0)
#    - 小北家灶咖ZAOKA (Lat: 22.9991, Lng: 120.199, Overall Score: 44.0)
#    - 彩豐樓 (Lat: 22.9993, Lng: 120.149, Overall Score: 32.0)
#    - 輕鬆點全日餐館 (Lat: 22.9868, Lng: 120.23, Overall Score: 44.0)
#    - 台南桂田渡假酒店 (Lat: 23.044, Lng: 120.243, Overall Score: 26.0)
#    - 涵花庭 Han's Garden (Lat: 22.9933, Lng: 120.185, Overall Score: 38.0)
#    - 金三益健康茶飲 (Lat: 23.007, Lng: 120.224, Overall Score: 44.0)
#    - 阿力海百匯餐廳 - 桂田酒店 (Lat: 23.0442, Lng: 120.243, Overall Score: 26.0)
#    - 一緒二咖啡 (Lat: 22.9959, Lng: 120.195, Overall Score: 44.0)
#    - 歐納牛排館 (Lat: 22.9918, Lng: 120.218, Overall Score: 26.0)
#    - Bark2輕餐食酒館 台南公園店 (Lat: 22.9942, Lng: 120.205, Overall Score: 38.0)
#    - 天心岩蔬食 (Lat: 22.9838, Lng: 120.186, Overall Score: 38.0)
#    - Dor,留手工義大利麵(友愛街店) (Lat: 22.9907, Lng: 120.2, Overall Score: 44.0)
#    - 醉地府 (Lat: 22.994, Lng: 120.2, Overall Score: 38.0)
#    - 福爾摩沙遊艇酒店 (Lat: 22.9986, Lng: 120.155, Overall Score: 32.0)
#    - 玄饌海鮮宴會館 (Lat: 22.9918, Lng: 120.152, Overall Score: 26.0)
#    - CHUJU雛菊餐桌-台南府前店 (Lat: 22.9927, Lng: 120.187, Overall Score: 44.0)
#    - 性格 (Lat: 22.9986, Lng: 120.207, Overall Score: 44.0)
#    - 阿堂鹹粥 (Lat: 22.9899, Lng: 120.198, Overall Score: 44.0)
#    - RÊVE 黑浮咖啡 台南永華店 (Lat: 22.9906, Lng: 120.172, Overall Score: 44.0)
#    - 鹿耳晚晚早餐(最後點餐14:00或完售提前打烊）& 鹿耳深夜甜點 (Lat: 22.9842, Lng: 120.215, Overall Score: 44.0)
#    - Autumn舒芙蕾熱鬆餅 (Lat: 22.9936, Lng: 120.201, Overall Score: 44.0)
#    - 勝利早點 (Lat: 22.9947, Lng: 120.218, Overall Score: 44.0)
#    - 阿公阿婆蛋餅 (Lat: 22.9994, Lng: 120.228, Overall Score: 44.0)
#    - 豆奶宗 (Lat: 22.9913, Lng: 120.193, Overall Score: 44.0)
#    - bistro88義法餐酒館 台南永華店 (Lat: 22.9892, Lng: 120.185, Overall Score: 38.0)
#    - 小巷裡的拾壹號-自家烘焙咖啡店 (Lat: 22.9931, Lng: 120.208, Overall Score: 44.0)
#    - A WEEK 乳酪 小鬆餅/台南 伴手禮 (Lat: 22.9926, Lng: 120.21, Overall Score: 44.0)
#    - 134巷內的女巫's (Lat: 22.9907, Lng: 120.223, Overall Score: 44.0)
#    - 悅津鹹粥 (Lat: 22.9976, Lng: 120.201, Overall Score: 44.0)
#    - 成真咖啡 台南正興店 (Lat: 22.9947, Lng: 120.197, Overall Score: 38.0)
#    - 倆人鍋鏟 (Lat: 23.001, Lng: 120.23, Overall Score: 44.0)
#    - PEKO PEKO (Lat: 22.9944, Lng: 120.201, Overall Score: 44.0)
#    - 首璽咖啡 SoSee Coffee (Lat: 22.9874, Lng: 120.23, Overall Score: 44.0)
#    - 阿杰手工蛋餅店 (Lat: 22.9826, Lng: 120.197, Overall Score: 44.0)
#    - 西羅殿牛肉湯 (Lat: 23.0015, Lng: 120.207, Overall Score: 44.0)
#    - 是吉咖啡 (Lat: 23.0041, Lng: 120.209, Overall Score: 44.0)
#    - 老丘早餐 (Lat: 22.995, Lng: 120.218, Overall Score: 44.0)
#    - 帕里諾咖啡 PANINO CAFE' (Lat: 22.9949, Lng: 120.211, Overall Score: 44.0)
#    - 永記虱目魚丸 (Lat: 22.99, Lng: 120.207, Overall Score: 44.0)
#    - Suns' Great / 向光旅行 (Lat: 23.001, Lng: 120.164, Overall Score: 44.0)
#    - Mumu小客廳 (Lat: 22.9908, Lng: 120.207, Overall Score: 44.0)
#    - T.F.P.臉紅的相遇 (Lat: 22.9825, Lng: 120.203, Overall Score: 44.0)
#    - L'esprit café 初衷咖啡 (Lat: 22.9975, Lng: 120.188, Overall Score: 44.0)
#    - io design studio (Lat: 23.008, Lng: 120.208, Overall Score: 38.0)
#    - T'WIN Coffee · 咖啡 / 云 (Lat: 22.9734, Lng: 120.224, Overall Score: 44.0)
#    - 開元路無名虱目魚 ‧ 肉燥飯 (Lat: 23.0082, Lng: 120.222, Overall Score: 44.0)
#    - 圈子 Brunch.Coffe - 臺南公園店 (Lat: 22.9965, Lng: 120.206, Overall Score: 44.0)
#    - 丹丹漢堡 永康店 (Lat: 23.0351, Lng: 120.23, Overall Score: 44.0)
#    - 南島夢遊 (Lat: 23.0091, Lng: 120.21, Overall Score: 44.0)
#    - 漫漫弄 (Lat: 22.9703, Lng: 120.187, Overall Score: 44.0)
#    - SisBro希絲柏甜食所 ｜舒芙蕾鬆餅｜早午餐 ｜千層蛋糕｜義大利麵｜ (Lat: 22.9846, Lng: 120.216, Overall Score: 44.0)
#    - 大勇街無名鹹粥 (Lat: 22.9898, Lng: 120.193, Overall Score: 44.0)
#    - 有一隻羊 A Sheep Cafe /售完提早打烊 /店休請見公告 (Lat: 23.006, Lng: 120.207, Overall Score: 44.0)
#    - 小曼谷 (Lat: 22.9912, Lng: 120.229, Overall Score: 44.0)
#    - 碳饅堡 (Lat: 22.9903, Lng: 120.192, Overall Score: 44.0)
#    - 花樓咖啡 Follow Coffee 二店 (Lat: 22.9965, Lng: 120.198, Overall Score: 44.0)
#    - 紅記早點 (Lat: 22.9825, Lng: 120.199, Overall Score: 44.0)
#    - 包成羊肉 (Lat: 22.9905, Lng: 120.197, Overall Score: 44.0)
#    - 和喫咖啡 (Lat: 22.9844, Lng: 120.21, Overall Score: 44.0)
#    - 狐獴先生 (Lat: 22.9916, Lng: 120.222, Overall Score: 44.0)
#    - 城東合作社咖啡 (Lat: 22.988, Lng: 120.216, Overall Score: 44.0)
#    - 艾柏達 | 咖啡 X Brunch (Lat: 22.9921, Lng: 120.189, Overall Score: 44.0)
#    - 拾分 (Lat: 22.9962, Lng: 120.217, Overall Score: 44.0)
#    - kokoni café (Lat: 22.9981, Lng: 120.201, Overall Score: 44.0)
#    - 霜花亭Brunch 公園店 (Lat: 22.9965, Lng: 120.206, Overall Score: 44.0)
#    - 少爺手作蛋餅專賣店-勝利總店 (Lat: 22.9883, Lng: 120.217, Overall Score: 44.0)
#    - 呂 早餐店手作蛋餅專賣 (Lat: 22.9811, Lng: 120.207, Overall Score: 44.0)
#    - 阿和肉燥飯 (Lat: 22.9891, Lng: 120.211, Overall Score: 44.0)
#    - 鐵門蛋捲 (Lat: 22.9871, Lng: 120.223, Overall Score: 44.0)
#    - 一方日朝食X喫茶 (Lat: 23.0032, Lng: 120.221, Overall Score: 44.0)
#    - Sunshine some shine 好曬餐飲部(收客至16：00） (Lat: 22.9913, Lng: 120.201, Overall Score: 44.0)
#    - 米寓 (Lat: 22.9959, Lng: 120.197, Overall Score: 44.0)
#    - 泰棒 Thai Bang Cuisine (Lat: 22.9915, Lng: 120.196, Overall Score: 38.0)
#    - Corridor Café(店休日請至FB粉絲專頁查看) (Lat: 22.9885, Lng: 120.178, Overall Score: 44.0)
#    - 廣仔虱目魚丸 (Lat: 22.9906, Lng: 120.206, Overall Score: 44.0)
#    - 他她咖啡館 (Lat: 23.0014, Lng: 120.2, Overall Score: 44.0)
#    - 壹零捌一 (Lat: 23.0007, Lng: 120.195, Overall Score: 44.0)
#    - 小二月飯湯 (Lat: 22.9878, Lng: 120.195, Overall Score: 44.0)
#    - 28 the loft (Lat: 23.0063, Lng: 120.207, Overall Score: 44.0)
#    - Bubuking鐵牛早餐車 (Lat: 22.9825, Lng: 120.199, Overall Score: 44.0)
#    - 台南七海魚肚魚皮專賣店 (Lat: 22.9776, Lng: 120.234, Overall Score: 44.0)
#    - 肥窩咖啡 (Lat: 23.001, Lng: 120.194, Overall Score: 44.0)
#    - 龍百貨（假日及例假日無訂位） (Lat: 22.9954, Lng: 120.205, Overall Score: 44.0)
#    - cafe.com噠慷咖啡（定休週三、不定休請搜尋IG/FB) (Lat: 23.0173, Lng: 120.208, Overall Score: 44.0)
#    - 來了就住一晚 (Lat: 22.9977, Lng: 120.201, Overall Score: 44.0)
#    - why東西 (Lat: 22.9907, Lng: 120.229, Overall Score: 44.0)
#    - 三赫老麵燒餅 (Lat: 23.02, Lng: 120.233, Overall Score: 44.0)
#    - 錫鼓 Tin Drum (Lat: 22.9905, Lng: 120.208, Overall Score: 44.0)
#    - 6吋盤早午餐-安平店 (Lat: 22.9899, Lng: 120.167, Overall Score: 44.0)
#    - 寓點 (Lat: 22.9921, Lng: 120.229, Overall Score: 44.0)
#    - 閒情茗品屋 (Lat: 22.9784, Lng: 120.188, Overall Score: 44.0)
#    - 七誠米粿 (Lat: 22.9958, Lng: 120.198, Overall Score: 44.0)
#    - 貓吐司堡專賣店 (Lat: 22.995, Lng: 120.221, Overall Score: 44.0)
#    - 蕃薯厝肉粿仔 (Lat: 23.0207, Lng: 120.279, Overall Score: 44.0)
#    - 窩星-米其林/台南/火鍋/東區 (Lat: 22.9873, Lng: 120.242, Overall Score: 38.0)
#    - 山記魚仔店 (Lat: 22.9891, Lng: 120.208, Overall Score: 38.0)
#    - 引引 臺南勝學店 (Lat: 23.0064, Lng: 120.231, Overall Score: 44.0)
#    - 翻滾吧！蛋捲 (Lat: 22.9905, Lng: 120.225, Overall Score: 44.0)
#    - CT Life小日子 (Lat: 23.0005, Lng: 120.198, Overall Score: 44.0)
#    - 有戶人家（營業時間依粉專公告為主） (Lat: 22.9929, Lng: 120.222, Overall Score: 44.0)
#    - 188宵夜早點 (Lat: 22.9962, Lng: 120.194, Overall Score: 44.0)
#    - 台南林百貨 (Lat: 22.9918, Lng: 120.203, Overall Score: 44.0)
#    - 赤崁樓 (Lat: 22.9975, Lng: 120.203, Overall Score: 44.0)
#    - 蜷尾家 (Lat: 22.9943, Lng: 120.197, Overall Score: 44.0)
#    - 和逸飯店 台南西門館 (Lat: 22.9873, Lng: 120.198, Overall Score: 44.0)
#    - 懷舊小棧杏仁豆腐冰 (Lat: 22.9827, Lng: 120.205, Overall Score: 44.0)
#    - 莉莉水果店 (Lat: 22.989, Lng: 120.204, Overall Score: 44.0)
#    - KADOYA喫茶店 (Lat: 22.9858, Lng: 120.216, Overall Score: 44.0)
#    - 同記安平豆花 (安平總店) (Lat: 22.9999, Lng: 120.153, Overall Score: 44.0)
#    - 深藍旗艦店*7/14起開放內用(預約制)* (Lat: 22.9923, Lng: 120.183, Overall Score: 44.0)
#    - 金色三麥 台南南紡店 (Lat: 22.9915, Lng: 120.233, Overall Score: 32.0)
#    - 黑工號嫩仙草 育樂店 (Lat: 22.9938, Lng: 120.215, Overall Score: 44.0)
#    - 泰成水果店 (Lat: 22.9944, Lng: 120.197, Overall Score: 44.0)
#    - 太陽牌冰品 (Lat: 22.9896, Lng: 120.21, Overall Score: 44.0)
#    - 双生綠豆沙牛奶 (Lat: 22.9964, Lng: 120.203, Overall Score: 44.0)
#    - 冰ㄉ• かき氷 二號 (Lat: 22.9903, Lng: 120.21, Overall Score: 44.0)
#    - 奇美食品幸福工廠 (Lat: 22.9487, Lng: 120.217, Overall Score: 44.0)
#    - 馥貴春重乳酪蛋糕-台南人氣必吃伴手禮美食 推薦 重乳酪蛋糕 彌月蛋糕禮盒試吃 起士蛋糕 在地人推薦伴手禮宅配服務 (Lat: 23.0192, Lng: 120.259, Overall Score: 38.0)
#    - 朕心加加 (Lat: 22.9944, Lng: 120.197, Overall Score: 44.0)
#    - Paripari apt. (Lat: 22.9958, Lng: 120.205, Overall Score: 44.0)
#    - 依蕾特布丁 (Lat: 22.9982, Lng: 120.174, Overall Score: 44.0)
#    - 清水堂愛玉專賣店 (Lat: 22.9933, Lng: 120.196, Overall Score: 44.0)
#    - 名坂奇洋菓子 (Lat: 22.98, Lng: 120.245, Overall Score: 38.0)
#    - 綠町抹茶專門店 (Lat: 22.9905, Lng: 120.207, Overall Score: 44.0)
#    - NINAO Gelato 蜷尾家 經典冰淇淋 (Lat: 22.9973, Lng: 120.147, Overall Score: 44.0)
#    - 自己的房間 (Lat: 22.9975, Lng: 120.201, Overall Score: 44.0)
#    - 南泉冰菓室 (Lat: 22.9985, Lng: 120.179, Overall Score: 44.0)
#    - 窄門咖啡館 (Lat: 22.9897, Lng: 120.205, Overall Score: 44.0)
#    - 蘇格蕾法式甜點 (Lat: 22.9968, Lng: 120.206, Overall Score: 44.0)
#    - 連得堂餅家 (Lat: 23.0004, Lng: 120.207, Overall Score: 44.0)
#    - 修安扁擔豆花 Xiu'an Douhua (Lat: 22.9972, Lng: 120.199, Overall Score: 44.0)
#    - 江水號 (Lat: 22.9941, Lng: 120.198, Overall Score: 44.0)
#    - 花見宇治抹茶甘味處 (Lat: 22.9951, Lng: 120.199, Overall Score: 44.0)
#    - 金得春捲 (Lat: 22.9976, Lng: 120.199, Overall Score: 44.0)
#    - 小茂屋 (Lat: 22.9931, Lng: 120.222, Overall Score: 44.0)
#    - 裕成水果行 (Lat: 22.994, Lng: 120.201, Overall Score: 44.0)
#    - 肥貓咖啡（肥貓故事館） (Lat: 22.9979, Lng: 120.195, Overall Score: 44.0)
#    - 我們工作室 (Lat: 23.0105, Lng: 120.226, Overall Score: 44.0)
#    - 綠皮開心果 冰淇淋工坊 (Lat: 22.9956, Lng: 120.204, Overall Score: 44.0)
#    - 四分之三法式甜點 (Lat: 22.9754, Lng: 120.203, Overall Score: 44.0)
#    - St.1 Cafe' / Work Room 一街咖啡 (Lat: 23.0197, Lng: 120.233, Overall Score: 44.0)
#    - 禮約蜂蜜彌月蛋糕 (Lat: 23.0284, Lng: 120.253, Overall Score: 44.0)
#    - 果核抵家 (Lat: 22.9964, Lng: 120.203, Overall Score: 44.0)
#    - 尋路。甜 (Lat: 23.004, Lng: 120.216, Overall Score: 44.0)
#    - 黑工號嫩仙草 赤崁店 (Lat: 22.9958, Lng: 120.202, Overall Score: 44.0)
#    - Mi Cazuela 移動的鍋子 (Lat: 22.9897, Lng: 120.206, Overall Score: 38.0)
#    - 松霖鍋燒始府 SONGLIN NABEYAKI NOODLE (Lat: 22.9999, Lng: 120.154, Overall Score: 44.0)
#    - 名東蛋糕 (Lat: 22.9951, Lng: 120.197, Overall Score: 44.0)
#    - Meller 墨樂咖啡 (Lat: 23.0007, Lng: 120.166, Overall Score: 44.0)
#    - 尚禾黑糖粉圓冰 (Lat: 22.9939, Lng: 120.196, Overall Score: 44.0)
#    - 甘單咖啡館 (Lat: 22.9942, Lng: 120.207, Overall Score: 44.0)
#    - a Room房間咖啡 (Lat: 22.985, Lng: 120.219, Overall Score: 44.0)
#    - 幸の町 雪花冰專賣店 (Lat: 22.9941, Lng: 120.196, Overall Score: 44.0)
#    - 台南-秘氏咖啡 (Lat: 22.9973, Lng: 120.199, Overall Score: 44.0)
#    - 同記安平豆花(安平2店) (Lat: 23.0029, Lng: 120.162, Overall Score: 44.0)
#    - 洁洁美食殿堂-永華店 (Lat: 22.9892, Lng: 120.184, Overall Score: 38.0)
#    - 【烘焙DIY】甘單作-台南崇德店 (Lat: 22.9756, Lng: 120.225, Overall Score: 44.0)
#    - 冰仔角 (Lat: 23.0135, Lng: 120.221, Overall Score: 44.0)
#    - 英式司康專賣所 (Lat: 22.9952, Lng: 120.199, Overall Score: 44.0)
#    - 八寶彬圓仔惠 (Lat: 22.9905, Lng: 120.197, Overall Score: 44.0)
#    - 阿川粉圓 (Lat: 22.9926, Lng: 120.196, Overall Score: 44.0)
#    - 麵家二眷牛肉麵 每週四固定公休，6/23、6/24多公休2天，最後內用3點，提早賣完提早打烊，謝謝? (Lat: 22.9889, Lng: 120.22, Overall Score: 44.0)
#    - 保安路米糕 (Lat: 22.9903, Lng: 120.197, Overall Score: 44.0)
#    - 新光三越台南新天地 (Lat: 22.9869, Lng: 120.198, Overall Score: 44.0)
#    - 阿卿杏仁茶 (Lat: 22.9905, Lng: 120.196, Overall Score: 44.0)
#    - 派星堂 PALAXY 台南裕平本店 (Lat: 22.9849, Lng: 120.241, Overall Score: 44.0)
#    - 兜空間 (Lat: 22.9918, Lng: 120.202, Overall Score: 44.0)
#    - 双利冰饌研習所 (Lat: 22.9919, Lng: 120.218, Overall Score: 44.0)
#    - 榮寓冰室 (Lat: 22.9748, Lng: 120.219, Overall Score: 44.0)
#    - 方蘭川布丁 - 台南伴手禮 (Lat: 23.0023, Lng: 120.165, Overall Score: 44.0)
#    - 鮮果診所(Juice Clinic) (Lat: 23.0046, Lng: 120.223, Overall Score: 38.0)
#    - 珍妮花與南洋杉（現場候位） (Lat: 22.9915, Lng: 120.218, Overall Score: 44.0)
#    - 寓･永恆 (Lat: 22.9891, Lng: 120.185, Overall Score: 44.0)
#    - 廿一酒吧 Bar 21 (Lat: 22.9899, Lng: 120.233, Overall Score: 26.0)
#    - 大韓名鍋韓式料理-台南總店 (Lat: 22.9978, Lng: 120.227, Overall Score: 44.0)
#    - 草屋Agave House (Lat: 22.9939, Lng: 120.206, Overall Score: 44.0)
#    - 打翻泡菜 (Lat: 22.982, Lng: 120.195, Overall Score: 44.0)
#    - 豬8色 (Lat: 23.0026, Lng: 120.195, Overall Score: 44.0)
#    - 涓豆腐 台南南紡店 (Lat: 22.9901, Lng: 120.233, Overall Score: 38.0)
#    - 兩餐두끼韓國年糕火鍋吃到飽 台南店 (Lat: 22.9959, Lng: 120.21, Overall Score: 44.0)
#    - 北村豆腐家 台南西門店 (Lat: 22.9868, Lng: 120.199, Overall Score: 44.0)
#    - 老韓家韓式廚房 (Lat: 22.987, Lng: 120.234, Overall Score: 38.0)
#    - bb.q CHICKEN南紡購物店 (Lat: 22.9901, Lng: 120.233, Overall Score: 44.0)
#    - 小東春韓食料理 (Lat: 22.9827, Lng: 120.205, Overall Score: 44.0)
#    - 吃道飽韓風火烤兩吃 (Lat: 23.0113, Lng: 120.232, Overall Score: 44.0)
#    - 韓福館 Han Fu Guan korean cuisine (Lat: 22.9908, Lng: 120.175, Overall Score: 44.0)
#    - KATZ 卡司韓拾炸雞 台南西門店 (Lat: 22.9937, Lng: 120.199, Overall Score: 44.0)
#    - 喆發樂樂鍋 - 火烤兩吃鍋 個人鍋 燒烤 部隊鍋 推薦平價 百元火鍋 家庭聚餐 朋友聚餐 (Lat: 22.9617, Lng: 120.189, Overall Score: 44.0)
#    - 八道江山韓式在地料理 (Lat: 23.0176, Lng: 120.192, Overall Score: 38.0)
#    - 韓巢炸雞 (Lat: 23.0406, Lng: 120.24, Overall Score: 44.0)
#    - 韓國先生Obba店 (Lat: 22.9952, Lng: 120.234, Overall Score: 44.0)
#    - 釜山異國料理館 (Lat: 23.0406, Lng: 120.24, Overall Score: 44.0)
#    - NENE CHICKEN 台南西門店 (Lat: 22.993, Lng: 120.198, Overall Score: 44.0)
#    - 明粥韓式料理 (Lat: 22.9854, Lng: 120.204, Overall Score: 44.0)
#    - 饗翻天臭臭鍋【永康北興店】 - 台南永康平價百元火鍋推薦 人氣必吃臭臭鍋 個人小火鍋 家庭朋友聚餐 自助吧暢飲 高CP值素食鍋 麻辣鍋 海鮮鍋 韓式部隊鍋 牛奶鍋 雞腿鍋 永康特色火鍋好評 首選 (Lat: 23.0142, Lng: 120.269, Overall Score: 44.0)
#    - 羊羊羊輕食 (Lat: 22.9901, Lng: 120.199, Overall Score: 44.0)
#    - 韓湘辣年糕-五妃店 (Lat: 22.9827, Lng: 120.199, Overall Score: 44.0)
#    - 起家雞韓式炸雞 台南永華店 (Lat: 22.9885, Lng: 120.188, Overall Score: 44.0)
#    - 韓館仁川 台南文賢店 (Lat: 23.012, Lng: 120.193, Overall Score: 44.0)
#    - 景福宮正宗韓食館 (Lat: 22.9954, Lng: 120.198, Overall Score: 44.0)
#    - 兩班家｜韓式熟成烤肉 台南店 (Lat: 22.9868, Lng: 120.199, Overall Score: 32.0)
#    - 大韓名鍋韓式料理-文南店 (Lat: 22.9827, Lng: 120.19, Overall Score: 44.0)
#    - 饗翻天臭臭鍋【永康南台店】 (Lat: 23.0231, Lng: 120.22, Overall Score: 44.0)
#    - 起家雞韓式炸雞 台南成功店 (Lat: 22.9974, Lng: 120.21, Overall Score: 38.0)
#    - Hello大邱辣年糕國安店 (Lat: 23.0218, Lng: 120.186, Overall Score: 44.0)
#    - 乳牛吐司-後甲店 (Lat: 22.9891, Lng: 120.234, Overall Score: 44.0)
#    - 慕十里韓式燒肉 (Lat: 22.9903, Lng: 120.247, Overall Score: 44.0)
#    - 明洞海苔飯捲崇明店 (Lat: 22.9757, Lng: 120.222, Overall Score: 44.0)
#    - BG韓式炸雞-台南成大店 (Lat: 22.9962, Lng: 120.216, Overall Score: 44.0)
#    - 臺灣歐巴-東區裕文店 (Lat: 22.9828, Lng: 120.238, Overall Score: 44.0)
#    - 高麗園銅盤烤肉 台南中山市場 (Lat: 22.9955, Lng: 120.21, Overall Score: 26.0)
#    - 韓式濟州鍋品料理 (Lat: 22.9894, Lng: 120.229, Overall Score: 44.0)
#    - 大韓名鍋韓式料理-歸仁大仁店 (Lat: 22.9671, Lng: 120.297, Overall Score: 44.0)
#    - 大老爺韓國烤肉台南店 (Lat: 22.9887, Lng: 120.238, Overall Score: 38.0)
#    - 豬頭妹韓式燒肉吃到飽餐廳 (Lat: 23.0198, Lng: 120.206, Overall Score: 38.0)
#    - Hello 大邱辣年糕崇德店 (Lat: 22.972, Lng: 120.227, Overall Score: 44.0)
#    - Mix Egg 台南九份子 (Lat: 23.0216, Lng: 120.186, Overall Score: 38.0)
#    - 歐八不是阿啾喜_國華旗艦店 (Lat: 22.9896, Lng: 120.197, Overall Score: 44.0)
#    - Isaac 安平店愛時刻奶油吐司專賣 (Lat: 22.9933, Lng: 120.179, Overall Score: 44.0)
#    - 漫草玖零 (Lat: 23.0004, Lng: 120.203, Overall Score: 32.0)
#    - Ai-Wei Bistro 愛薇餐酒館 (Lat: 22.9978, Lng: 120.204, Overall Score: 26.0)
#    - THE ONE Lounge Bar (Lat: 22.9975, Lng: 120.187, Overall Score: 26.0)
#    - Bena Bistro(貝納餐酒館） (Lat: 22.9954, Lng: 120.206, Overall Score: 38.0)
#    - 墨閣 Moger (Lat: 22.9824, Lng: 120.199, Overall Score: 44.0)
#    - 沃野18 OhYeah18 (Lat: 22.9945, Lng: 120.221, Overall Score: 38.0)
#    - 鯤島 Khuntor (Lat: 23.0031, Lng: 120.222, Overall Score: 38.0)
#    - Simple Plan 咖啡小酒館 (Lat: 22.9945, Lng: 120.2, Overall Score: 44.0)
#    - Tunnel Bar（隧道酒吧/餐酒館） (Lat: 22.9958, Lng: 120.2, Overall Score: 26.0)
#    - 在島之後After Island. 餐酒館 (Lat: 22.9935, Lng: 120.226, Overall Score: 38.0)
#    - Corner Square 咫尺角落 (Lat: 22.9924, Lng: 120.21, Overall Score: 44.0)
#    - 後面還有 小酒館 (Lat: 23.0018, Lng: 120.2, Overall Score: 44.0)
#    - 舞鶴燒烤舖 (Lat: 22.9918, Lng: 120.195, Overall Score: 44.0)
#    - The Mezz 牛排龍蝦館 - 台南遠東香格里拉 (Lat: 22.9964, Lng: 120.215, Overall Score: 26.0)
#    - 木目麦酒 (Lat: 22.9882, Lng: 120.209, Overall Score: 44.0)
#    - The Han-Jia Pairing Dinner 酣呷餐酒 (Lat: 22.9867, Lng: 120.197, Overall Score: 44.0)
#    - Crazy bar 餐酒館 (Lat: 23.0374, Lng: 120.236, Overall Score: 38.0)
#    - 杏花村 (Lat: 22.9941, Lng: 120.195, Overall Score: 38.0)
#    - Euphoria酒。餐 (Lat: 22.9932, Lng: 120.208, Overall Score: 44.0)
#    - 大乱歩 (Lat: 23.0003, Lng: 120.198, Overall Score: 38.0)
#    - Bar C•L•C - 招待所 (Lat: 23.0007, Lng: 120.195, Overall Score: 44.0)
#    - Phowa (Lat: 22.9969, Lng: 120.201, Overall Score: 44.0)
#    - 敘酒Hang Out Bar (Lat: 22.9887, Lng: 120.196, Overall Score: 44.0)
#    - Bar TCRC 前科累累俱樂部 (Lat: 22.9969, Lng: 120.201, Overall Score: 26.0)
#    - 散漫酒館 (Lat: 22.9878, Lng: 120.196, Overall Score: 44.0)
#    - 嚥·台南 (Lat: 23.0003, Lng: 120.206, Overall Score: 44.0)
#    - 深夜 Glasses of midnight (Lat: 22.9896, Lng: 120.227, Overall Score: 44.0)
#    - 小魚兒重慶烤魚 (Lat: 23.0001, Lng: 120.201, Overall Score: 44.0)
#    - 小椿食堂 (Lat: 22.9903, Lng: 120.199, Overall Score: 44.0)
#    - 酒河豚 (Lat: 22.9941, Lng: 120.206, Overall Score: 44.0)
#    - 魚小二重慶烤魚-台南總店 (Lat: 22.9987, Lng: 120.231, Overall Score: 38.0)
#    - 大河屋 燒肉丼 串燒-台南仁德家樂福店 (Lat: 22.9724, Lng: 120.247, Overall Score: 44.0)
#    - Bula冷奶油咖椰吐司-台南總店 (Lat: 22.9946, Lng: 120.2, Overall Score: 44.0)
#    - 大河屋 燒肉丼 串燒- 台南新光三越中山店 (Lat: 22.9955, Lng: 120.21, Overall Score: 44.0)
#    - 愛夏子海安店 (Lat: 22.9926, Lng: 120.196, Overall Score: 38.0)
#    - 益田居酒屋 (Lat: 22.9878, Lng: 120.195, Overall Score: 38.0)
#    - 熊咖哩クマカレー (Lat: 22.995, Lng: 120.21, Overall Score: 38.0)
#    - 閤苑坊串燒酒場 (Lat: 23.0008, Lng: 120.198, Overall Score: 38.0)
#    - 樂樂日式本格居酒屋 (Lat: 22.9911, Lng: 120.208, Overall Score: 44.0)
#    - 室町鰻丼三吃 (Lat: 22.9978, Lng: 120.196, Overall Score: 38.0)
#    - 玩食燒日式串燒店 (Lat: 22.9952, Lng: 120.233, Overall Score: 44.0)
#    - 姚燒鳥 (Lat: 22.9981, Lng: 120.198, Overall Score: 38.0)
#    - 敲之助酒肆專門店 (Lat: 22.9905, Lng: 120.234, Overall Score: 26.0)
#    - 900度串燒工坊 (Lat: 22.9923, Lng: 120.179, Overall Score: 26.0)
#    - 3号燒烤美食 (Lat: 22.987, Lng: 120.219, Overall Score: 44.0)
#    - 日本再生酒場 台南店 (Lat: 22.9897, Lng: 120.197, Overall Score: 38.0)
#    - 邊疆燒烤 (Lat: 22.9978, Lng: 120.207, Overall Score: 38.0)
#    - 肉慾先生炭烤牛排丼飯 永康店 (Lat: 23.0054, Lng: 120.235, Overall Score: 44.0)
#    - 九分麻微辣 (Lat: 23.0234, Lng: 120.259, Overall Score: 38.0)
#    - 窩燒man (Lat: 22.9911, Lng: 120.196, Overall Score: 44.0)
#    - 咪咪笑串燒 (Lat: 23.0, Lng: 120.196, Overall Score: 44.0)
#    - 合伙燒 日式關東煮燒烤 (Lat: 22.9919, Lng: 120.195, Overall Score: 38.0)
#    - 精一杯串燒（粉絲團有第一手消息） (Lat: 22.9947, Lng: 120.182, Overall Score: 38.0)
#    - 福島日本料理 (Lat: 22.9861, Lng: 120.223, Overall Score: 38.0)
#    - 碳呼吸碳烤熱炒 (Lat: 23.0019, Lng: 120.205, Overall Score: 44.0)
#    - 双町 (Lat: 22.9947, Lng: 120.205, Overall Score: 44.0)
#    - 花食間 手作 (Lat: 22.9978, Lng: 120.196, Overall Score: 44.0)
#    - 晨光森林複合式餐飲 (Lat: 23.0426, Lng: 120.203, Overall Score: 44.0)
#    - 京享鐵板燒 (安中店) (Lat: 23.0406, Lng: 120.2, Overall Score: 44.0)
#    - 魔力牛牛排館 台南安中店 安南區超值CP平價人氣必吃牛排 (Lat: 23.0392, Lng: 120.202, Overall Score: 44.0)
#    - 昱琳窯烤pizza (Lat: 23.0411, Lng: 120.199, Overall Score: 44.0)
#    - 鄉村漢堡 (Lat: 23.0368, Lng: 120.206, Overall Score: 44.0)
#    - 七陶里季 (Lat: 23.0368, Lng: 120.203, Overall Score: 44.0)
#    - HOME'S 初．時光 (Lat: 23.0403, Lng: 120.2, Overall Score: 44.0)
#    - 米食S&A (Lat: 23.0371, Lng: 120.206, Overall Score: 44.0)
#    - 麥當勞-安南北安店 (Lat: 23.0419, Lng: 120.203, Overall Score: 44.0)
#    - 台南市安南區怡安路二段170號 (Lat: 23.0439, Lng: 120.199, Overall Score: 44.0)
#    - 雲福小炒 (Lat: 23.0423, Lng: 120.204, Overall Score: 44.0)
#    - 五十一番日式居食屋 (Lat: 23.0403, Lng: 120.203, Overall Score: 44.0)
#    - 福葉軒 (Lat: 23.0403, Lng: 120.2, Overall Score: 44.0)
#    - 21世紀風味館 (Lat: 23.0425, Lng: 120.203, Overall Score: 44.0)
#    - 傑的小店 (Lat: 23.0405, Lng: 120.205, Overall Score: 44.0)
#    - 都 日本料理 (Lat: 23.0427, Lng: 120.203, Overall Score: 44.0)
#    - 火考の口未 (Lat: 23.0423, Lng: 120.204, Overall Score: 44.0)
#    - 日十。安中店 (Lat: 23.0371, Lng: 120.206, Overall Score: 44.0)
#    - Marco Pizza Jacob's store (Lat: 23.0141, Lng: 120.209, Overall Score: 44.0)
#    - 蠔記中式速食 (Lat: 23.016, Lng: 120.211, Overall Score: 44.0)
#    - 麥味登 育德店 (Lat: 23.0154, Lng: 120.207, Overall Score: 44.0)
#    - 北海燒炒物語 (Lat: 23.0194, Lng: 120.206, Overall Score: 44.0)
#    - 安來素食簡餐 (Lat: 23.0187, Lng: 120.209, Overall Score: 44.0)
#    - 延平市場客家村 (Lat: 23.0137, Lng: 120.213, Overall Score: 44.0)
#    - 老吳冰室 (Lat: 22.9861, Lng: 120.2, Overall Score: 44.0)
#    - 咕嚕家庭料理館 (Lat: 22.9821, Lng: 120.206, Overall Score: 44.0)
#    - 阿地牛排館A-Di Steakhouse (Lat: 22.9816, Lng: 120.204, Overall Score: 44.0)
#    - 摩斯漢堡 台南健康店 (Lat: 22.9811, Lng: 120.208, Overall Score: 44.0)
#    - The Sober Foodie 食上主義餐酒館 (Lat: 22.9807, Lng: 120.208, Overall Score: 44.0)
#    - 初燒肉 Hatsu Yakiniku (Lat: 22.9866, Lng: 120.2, Overall Score: 44.0)
#    - 甲侯八拉麵-健康店 (Lat: 22.9816, Lng: 120.202, Overall Score: 44.0)
#    - 水餃飽飽 (Lat: 22.9824, Lng: 120.208, Overall Score: 44.0)
#    - 酒鬍子創意鍋燒 (Lat: 22.9826, Lng: 120.208, Overall Score: 44.0)
#    - 玉婆壽司店 (Lat: 22.9897, Lng: 120.207, Overall Score: 44.0)
#    - 好好的牛肉麵 (Lat: 22.9916, Lng: 120.212, Overall Score: 44.0)
#    - 值得小炒 (Lat: 22.9669, Lng: 120.192, Overall Score: 44.0)
#    - 鉄輪 ジンギスカン (Lat: 22.995, Lng: 120.2, Overall Score: 44.0)
#    - 驢子散步西班牙私廚 預約制 (Lat: 22.989, Lng: 120.208, Overall Score: 44.0)
#    - 炒飯專家 (Lat: 22.9911, Lng: 120.206, Overall Score: 44.0)
#    - 吾庵食業-中西推薦咖哩飯|人氣咖哩|熱門咖哩|人氣餐廳|必吃咖哩|在地推薦餐廳 (Lat: 22.9865, Lng: 120.208, Overall Score: 44.0)
#    - 自然熟clean & wild eats (Lat: 22.994, Lng: 120.21, Overall Score: 44.0)
#    - DOMO Pasta多麼 義大利麵/小東門咖喱-台南民族店 (Lat: 22.9946, Lng: 120.21, Overall Score: 44.0)
#    - 雙好港式燒臘 (Lat: 22.9898, Lng: 120.207, Overall Score: 44.0)
#    - 英倫港式餐廳 (Lat: 22.9813, Lng: 120.2, Overall Score: 44.0)
#    - 陶板屋 台南忠義店 (Lat: 22.9914, Lng: 120.203, Overall Score: 44.0)
#    - 愛夏子 (Lat: 22.986, Lng: 120.202, Overall Score: 44.0)
#    - 濃園滿漢餐廳 (Lat: 22.9905, Lng: 120.221, Overall Score: 44.0)
#    - 三胡町-義式餐館 (Lat: 22.9881, Lng: 120.216, Overall Score: 44.0)
#    - 饕弄杯 (Lat: 22.9888, Lng: 120.216, Overall Score: 38.0)
#    - Brick磚塊 Bar&Brunch (Lat: 22.9945, Lng: 120.197, Overall Score: 44.0)
#    - Nest _de_O_Bar (Lat: 23.0008, Lng: 120.197, Overall Score: 44.0)
#    - 溫格樓ONEderland (Lat: 23.0018, Lng: 120.197, Overall Score: 44.0)
#    - 双赫日式拉麵 (Lat: 22.9983, Lng: 120.197, Overall Score: 44.0)
#    - 滿座鮮魚湯 (Lat: 22.9975, Lng: 120.195, Overall Score: 44.0)
#    - 根うなぎ串居酒屋 (Lat: 22.999, Lng: 120.197, Overall Score: 44.0)
#    - 無名早餐店 (Lat: 22.9972, Lng: 120.194, Overall Score: 44.0)
#    - 吳留手串燒居酒屋-台南店 (Lat: 22.9973, Lng: 120.197, Overall Score: 44.0)
#    - 村吉蔬素食養生創意料理 (Lat: 22.9988, Lng: 120.199, Overall Score: 44.0)
#    - 五分鐘找餐-台南民生店 | 創意飯糰 ｜ 特色鍋燒 ｜ 獨特漢堡 ｜中西區 ｜ 早午餐必吃 ｜ 台南美食 (Lat: 22.9975, Lng: 120.19, Overall Score: 44.0)
#    - 北園義法小館 (Lat: 23.0121, Lng: 120.223, Overall Score: 44.0)
#    - 繆思義式餐坊 (Lat: 23.0109, Lng: 120.224, Overall Score: 44.0)
#    - 哈慕林鐵板燒 (Lat: 23.0073, Lng: 120.221, Overall Score: 44.0)
#    - 福樂牛排 (Lat: 23.0131, Lng: 120.221, Overall Score: 44.0)
#    - 張家牛肉麵 (Lat: 23.0137, Lng: 120.227, Overall Score: 44.0)
#    - 沖繩貓和風洋食 (Lat: 23.0138, Lng: 120.218, Overall Score: 44.0)
#    - 青木森串燒小料理 (Lat: 23.0142, Lng: 120.221, Overall Score: 44.0)
#    - KLG 炸雞 (長榮店) (Lat: 23.0087, Lng: 120.221, Overall Score: 44.0)
#    - 大友牛肉麵 (Lat: 23.0105, Lng: 120.223, Overall Score: 44.0)
#    - 晨間廚房早午餐台南北園店/蛋餅/早餐/麵/成大城 (Lat: 23.011, Lng: 120.224, Overall Score: 44.0)
#    - 樸九鼎鮮火鍋 (Lat: 23.0137, Lng: 120.227, Overall Score: 44.0)
#    - 客家味小炒 (Lat: 23.0119, Lng: 120.22, Overall Score: 44.0)
#    - 台南市長榮路高架橋旁 關東煮 (Lat: 23.0113, Lng: 120.22, Overall Score: 44.0)
#    - 晨翊早餐店 (Lat: 23.0135, Lng: 120.219, Overall Score: 44.0)
#    - QQ堡 (Lat: 23.0077, Lng: 120.226, Overall Score: 44.0)
#    - 豬排專賣店 (Lat: 23.0099, Lng: 120.223, Overall Score: 44.0)
#    - 同心億麵攤 (Lat: 23.0088, Lng: 120.224, Overall Score: 44.0)
#    - 胖老爹美式炸雞 台南長榮店 (Lat: 23.0074, Lng: 120.221, Overall Score: 44.0)
#    - 一坪壽司-永康店 (Lat: 23.0152, Lng: 120.226, Overall Score: 44.0)
#    - 小豪州沙茶爐中山店 (Lat: 22.9947, Lng: 120.208, Overall Score: 44.0)
#    - 客家莊客家美食 (Lat: 22.9985, Lng: 120.2, Overall Score: 44.0)
#    - 裏葉（營業資訊請看IG) (Lat: 23.0023, Lng: 120.201, Overall Score: 44.0)
#    - Nani麵 (Lat: 22.998, Lng: 120.201, Overall Score: 44.0)
#    - Order義式料理 (Lat: 22.9969, Lng: 120.204, Overall Score: 44.0)
#    - 藏富居酒屋 (Lat: 22.9994, Lng: 120.202, Overall Score: 44.0)
#    - 樂居酒屋 (Lat: 22.997, Lng: 120.206, Overall Score: 44.0)
#    - 瓦城泰國料理 - 台南三越中山店 (Lat: 22.9955, Lng: 120.21, Overall Score: 44.0)
#    - 九龍小吃店 (Lat: 22.9993, Lng: 120.211, Overall Score: 44.0)
#    - 寶來軒 (Lat: 23.002, Lng: 120.206, Overall Score: 44.0)
#    - 活水早餐店 (Lat: 22.9958, Lng: 120.205, Overall Score: 44.0)
#    - 說吧 SOBA (不定休，詳細資訊及營業時間依IG公告為主，無接待七歲以下孩童，最後點餐18:00） (Lat: 22.9815, Lng: 120.209, Overall Score: 44.0)
#    - ShuangMu双木漢堡 (Lat: 22.9804, Lng: 120.213, Overall Score: 44.0)
#    - 香川麵館 (Lat: 22.9781, Lng: 120.213, Overall Score: 44.0)
#    - 8818 Pizza Restaurant 比薩屋 (Lat: 22.9815, Lng: 120.207, Overall Score: 44.0)
#    - 塚越七町目 麵食堂 (Lat: 22.981, Lng: 120.213, Overall Score: 44.0)
#    - 集雅朵法式餐廳 (Lat: 22.9805, Lng: 120.207, Overall Score: 44.0)
#    - 一九九九茶水灘小吃店 (Lat: 22.9771, Lng: 120.214, Overall Score: 44.0)
#    - 蔬食者小館 (Lat: 22.9782, Lng: 120.214, Overall Score: 44.0)
#    - 麥當勞-台南健康店 (Lat: 22.9814, Lng: 120.211, Overall Score: 44.0)
#    - 食べ·オム洋食歐姆専門店-台南 人氣必吃美食 平價日式蛋包飯 銅板排隊料理 聚會聚餐首選推薦 (Lat: 22.978, Lng: 120.213, Overall Score: 44.0)
#    - 來上座美食早點 (Lat: 22.9815, Lng: 120.216, Overall Score: 44.0)
#    - 74號早餐店 (Lat: 22.9814, Lng: 120.21, Overall Score: 44.0)
#    - 拉亞漢堡 台南大同 (Lat: 22.978, Lng: 120.213, Overall Score: 44.0)
#    - BOP餐酒館 (Lat: 22.9809, Lng: 120.213, Overall Score: 44.0)
#    - 尋早早餐 (Lat: 22.9824, Lng: 120.208, Overall Score: 44.0)
#    - 晨間廚房早午餐台南大同店/蛋餅/早餐/麵/南區新生社區 (Lat: 22.9774, Lng: 120.213, Overall Score: 44.0)
#    - 過客甜點 (Passer Dasserr) (Lat: 22.977, Lng: 120.215, Overall Score: 44.0)
#    - 歐栗廚房 (Lat: 22.9757, Lng: 120.214, Overall Score: 44.0)
#    - 尚好烤肉(台南旗艦店) (Lat: 22.9763, Lng: 120.214, Overall Score: 44.0)
#    - 堤米和洋料理簡餐 (Lat: 22.9891, Lng: 120.205, Overall Score: 44.0)
#    - 陳家蚵捲 (Lat: 23.0004, Lng: 120.162, Overall Score: 44.0)
#    - 南門牛肉麵 (Lat: 22.9856, Lng: 120.204, Overall Score: 44.0)
#    - 田麵匠 (Lat: 22.99, Lng: 120.207, Overall Score: 44.0)
#    - 心丼食堂-日本料理美食 壽司 丼飯外帶餐盒 公司企業機關團體便當(人氣必吃) (Lat: 22.9891, Lng: 120.208, Overall Score: 44.0)
#    - 老宅·南 (Lat: 22.9848, Lng: 120.205, Overall Score: 44.0)
#    - 馬鈴薯先生Mr. Potato (Lat: 22.9895, Lng: 120.164, Overall Score: 44.0)
#    - 鄉舍漢堡 (Lat: 22.9873, Lng: 120.164, Overall Score: 44.0)
#    - 三皇三家-億載店 (Lat: 22.9924, Lng: 120.165, Overall Score: 44.0)
#    - 億載鍋燒意麵 (Lat: 22.9895, Lng: 120.164, Overall Score: 44.0)
#    - 馨香早餐屋 (Lat: 22.9892, Lng: 120.164, Overall Score: 44.0)
#    - 東北酸白菜火煱 (Lat: 22.9927, Lng: 120.165, Overall Score: 44.0)
#    - 中西式雅雪早午餐 (Lat: 23.0375, Lng: 120.128, Overall Score: 44.0)
#    - 娜君早餐店 (Lat: 23.0379, Lng: 120.127, Overall Score: 44.0)
#    - 風車古早味（紫藤屋）/ 鹿耳門天后宮邊 (Lat: 23.0372, Lng: 120.124, Overall Score: 44.0)
#    - 美又堡早餐店 (Lat: 22.9311, Lng: 120.231, Overall Score: 44.0)
#    - 聯芳小樹米食主義（近奇美博物館 十鼓 台南捷絲旅 保安車站 嘉南大學） (Lat: 22.9302, Lng: 120.231, Overall Score: 44.0)
#    - 千香漢堡 仁德保安店 (Lat: 22.9306, Lng: 120.231, Overall Score: 44.0)
#    - 保安鹽水手工意麵 (Lat: 22.9308, Lng: 120.231, Overall Score: 44.0)
#    - 弘爺漢堡(仁德保安店) (Lat: 22.9306, Lng: 120.23, Overall Score: 44.0)
#    - 吳家肉燥飯 (Lat: 22.9313, Lng: 120.231, Overall Score: 44.0)
#    - 金魯味飯館 (Lat: 22.9306, Lng: 120.231, Overall Score: 44.0)
#    - 永持家私品牌行銷處 (Lat: 22.9312, Lng: 120.23, Overall Score: 44.0)
#    - 李家小吃(肉燥飯) (Lat: 22.9309, Lng: 120.231, Overall Score: 44.0)
#    - Bao’an Pasta保安工寓咖啡 (Lat: 22.9294, Lng: 120.231, Overall Score: 44.0)
#    - 富林漢堡 (Lat: 22.9291, Lng: 120.231, Overall Score: 44.0)
#    - 印尼料理小吃 (Lat: 22.9987, Lng: 120.212, Overall Score: 44.0)
#    - 福島壽司 安平店－台南安平｜2023網友推薦必吃日本料理餐廳 網紅好評外帶外送炸蝦壽司 網美首選人氣聚餐外帶多人日式餐盒 高CP值熱門 好吃商務便當 散步美食 評價 打卡野餐價格 (Lat: 22.9889, Lng: 120.176, Overall Score: 44.0)
#    - 鮮來碗海鮮粥 (Lat: 22.9891, Lng: 120.169, Overall Score: 44.0)
#    - 凱荳寵物家庭餐廳 (Lat: 22.9856, Lng: 120.169, Overall Score: 44.0)
#    - 菜香小廚 (Lat: 22.9896, Lng: 120.171, Overall Score: 44.0)
#    - 167號小炒 (Lat: 22.9891, Lng: 120.168, Overall Score: 44.0)
#    - 一起找餐吧 (Lat: 22.9886, Lng: 120.167, Overall Score: 44.0)
#    - 府城食府正宗台南料理-安平總店 (Lat: 22.9879, Lng: 120.175, Overall Score: 44.0)
#    - Olga俄羅斯烤肉 (Lat: 22.9875, Lng: 120.168, Overall Score: 44.0)
#    - G蛋食研所X會中Cafe - Brunch/輕食早午餐/減脂健康餐盒/蔬果咖哩/慢熬鮮骨火鍋/精品手沖咖啡/職人甜點 (Lat: 22.9894, Lng: 120.171, Overall Score: 44.0)
#    - 張姐小吃店 (Lat: 22.989, Lng: 120.168, Overall Score: 44.0)
#    - SUBWAY潛艇堡.沙拉台南安平店 (Lat: 22.9891, Lng: 120.171, Overall Score: 44.0)
#    - 千香漢堡郡平店 (Lat: 22.9892, Lng: 120.169, Overall Score: 44.0)
#    - 東饌魚翅 (Lat: 22.9883, Lng: 120.175, Overall Score: 44.0)
#    - 麓麓漢堡-府平店 (Lat: 22.987, Lng: 120.168, Overall Score: 44.0)
#    - 張記燒臘坊 (Lat: 22.9893, Lng: 120.168, Overall Score: 44.0)
#    - 晨間廚房早午餐安平國平店/蛋餅/早餐/麵/府平公園 (Lat: 22.9892, Lng: 120.171, Overall Score: 44.0)
#    - 阿錤師四季料理 (Lat: 22.9868, Lng: 120.167, Overall Score: 44.0)
#    - 鄭海產 (Lat: 22.9894, Lng: 120.169, Overall Score: 44.0)
#    - 黃記好吃雞肉 (Lat: 22.9892, Lng: 120.169, Overall Score: 44.0)
#    - 弘爺漢堡安平健康店 (Lat: 22.9854, Lng: 120.168, Overall Score: 44.0)
#    - 良人煮鍋｜手作鍋物｜台南最美火鍋品牌｜ 台南安平區火鍋（店休日請至FB粉絲） (Lat: 22.9828, Lng: 120.168, Overall Score: 44.0)
#    - G•BURGER台南安平店 (Lat: 22.985, Lng: 120.168, Overall Score: 44.0)
#    - 瑪哈印度餐廳Maharaja indian Restaurant (Lat: 23.0032, Lng: 120.222, Overall Score: 44.0)
#    - 亞芙英式餐廳 (Lat: 23.0035, Lng: 120.219, Overall Score: 44.0)
#    - 麥雅印度咖喱 Maiya Indian Curry Halal (Lat: 23.0035, Lng: 120.219, Overall Score: 44.0)
#    - 紅象鐵板燒 (Lat: 23.0032, Lng: 120.222, Overall Score: 44.0)
#    - 庫肯花園餐廳 (Lat: 22.9957, Lng: 120.221, Overall Score: 44.0)
#    - 夏慕尼新香榭鉄板燒台南公園南店 (Lat: 23.0027, Lng: 120.202, Overall Score: 38.0)
#    - 大台南西餐廳工會 (Lat: 22.9951, Lng: 120.202, Overall Score: 44.0)
#    - 一羽鯨吞 地雞料理居酒屋 (Lat: 23.002, Lng: 120.199, Overall Score: 44.0)
#    - 來一碗牛肉麵 (Lat: 22.9996, Lng: 120.206, Overall Score: 44.0)
#    - 好田·米鬆餅 |宮後街16號| (Lat: 22.9965, Lng: 120.199, Overall Score: 44.0)
#    - 伍肆貳早餐吧 (Lat: 23.0325, Lng: 120.141, Overall Score: 44.0)
#    - 燕霞小吃 (Lat: 23.0324, Lng: 120.14, Overall Score: 44.0)
#    - 蔡家古早味小吃2店 (Lat: 23.0195, Lng: 120.134, Overall Score: 44.0)
#    - 吳一刀老巢窩 (Lat: 23.0314, Lng: 120.141, Overall Score: 44.0)
#    - 橄饗家西班牙嚴選美食餐廳Como en casa gourmet (Lat: 22.9984, Lng: 120.149, Overall Score: 38.0)
#    - Ellen 3 Cafe ( indonesia ) (Lat: 23.0005, Lng: 120.21, Overall Score: 44.0)
#    - Cocina Quesadilla (Lat: 23.0036, Lng: 120.215, Overall Score: 44.0)
#    - Principe 原則 (Lat: 22.9993, Lng: 120.211, Overall Score: 44.0)
#    - 綠屋異國風味美食館 (Lat: 23.0019, Lng: 120.215, Overall Score: 44.0)
#    - 尼法 (Lat: 23.0038, Lng: 120.217, Overall Score: 38.0)
#    - (朝代大飯店)皇朝中餐廳 (Lat: 22.9981, Lng: 120.208, Overall Score: 44.0)
#    - 豐伍玖早午蔬食 (Lat: 23.0041, Lng: 120.216, Overall Score: 44.0)
#    - 日十。早午食台南成功店 (Lat: 22.9993, Lng: 120.209, Overall Score: 44.0)
#    - 印尼美食 (Lat: 22.9998, Lng: 120.212, Overall Score: 44.0)
#    - 五黑家日式拉麵 (Lat: 23.0048, Lng: 120.21, Overall Score: 44.0)
#    - 台北永和豆漿 台南成功店 (Lat: 22.9979, Lng: 120.207, Overall Score: 44.0)
#    - 素食早點 (Lat: 22.9745, Lng: 120.296, Overall Score: 44.0)
#    - 米珠排骨飯 (Lat: 22.9739, Lng: 120.296, Overall Score: 44.0)
#    - 炭吉168韓國料理 (Lat: 22.9734, Lng: 120.291, Overall Score: 44.0)
#    - 阿堂活蝦海產 (Lat: 22.9734, Lng: 120.291, Overall Score: 44.0)
#    - 珍珍牛肉爐 (Lat: 22.9739, Lng: 120.288, Overall Score: 44.0)
#    - 田園素食 (Lat: 22.9731, Lng: 120.296, Overall Score: 44.0)
#    - 素餐車：素湯包、水蒸餃、素圓 (Lat: 22.9728, Lng: 120.296, Overall Score: 44.0)
#    - 歸仁豆乳雞 (Lat: 22.9732, Lng: 120.295, Overall Score: 44.0)
#    - 鄰家美食 (Lat: 22.9723, Lng: 120.297, Overall Score: 44.0)
#    - 1 (Lat: 22.9731, Lng: 120.295, Overall Score: 44.0)
#    - WOOW House 我屋 (Lat: 22.9866, Lng: 120.202, Overall Score: 44.0)
#    - 老程麵館 (Lat: 23.0481, Lng: 120.179, Overall Score: 44.0)
#    - Hellotime 你好時光 (Lat: 23.0474, Lng: 120.182, Overall Score: 44.0)
#    - 九湯屋-安中店 (Lat: 23.0474, Lng: 120.182, Overall Score: 44.0)
#    - 御品美食饗食堂/台南外燴 台南辦桌 安南美食 安南熱炒 安南合菜 安南聚餐 安南燒烤 台南燒烤 (Lat: 23.053, Lng: 120.179, Overall Score: 44.0)
#    - 馬克7號（MARK VII) 複合式餐飲 (Lat: 23.0543, Lng: 120.178, Overall Score: 44.0)
#    - 弘爺漢堡 -安南店 (海東國小) (Lat: 23.0485, Lng: 120.177, Overall Score: 44.0)
#    - 明德冷熱飲 (Lat: 23.0491, Lng: 120.176, Overall Score: 44.0)
#    - 安中路桂水餃 (Lat: 23.0489, Lng: 120.176, Overall Score: 44.0)
#    - 欣福龍海鮮餐廳 (Lat: 23.0476, Lng: 120.181, Overall Score: 44.0)
#    - 總督廣式燒臘 (Lat: 23.048, Lng: 120.179, Overall Score: 44.0)
#    - 安南排骨 (Lat: 23.053, Lng: 120.179, Overall Score: 44.0)
#    - 晨間廚房早午餐安南海佃店/蛋餅/早餐/麵 (Lat: 23.0522, Lng: 120.18, Overall Score: 44.0)
#    - 鱻海味自助餐 (Lat: 23.0533, Lng: 120.178, Overall Score: 44.0)
#    - 千香漢堡 安中店 (Lat: 23.0485, Lng: 120.177, Overall Score: 44.0)
#    - 蓁寶早午餐 (Lat: 23.0499, Lng: 120.181, Overall Score: 44.0)
#    - 澄香 • 鍋語 (Lat: 23.0474, Lng: 120.182, Overall Score: 44.0)
#    - 早安早安早餐專賣 (Lat: 23.0487, Lng: 120.176, Overall Score: 44.0)
#    - 富林早餐店 (Lat: 23.0484, Lng: 120.183, Overall Score: 44.0)
#    - 美而美安中店 (Lat: 23.0492, Lng: 120.175, Overall Score: 44.0)
#    - 一拜居酒屋いっぱい (Lat: 23.048, Lng: 120.18, Overall Score: 44.0)
#    - 紅瓦厝甕仔鷄 (Lat: 22.9677, Lng: 120.294, Overall Score: 44.0)
#    - 二街館 (Lat: 22.9664, Lng: 120.292, Overall Score: 44.0)
#    - 36町pasta (Lat: 22.9671, Lng: 120.293, Overall Score: 44.0)
#    - 大通一零八私房料理 (Lat: 22.968, Lng: 120.294, Overall Score: 44.0)
#    - Y博牛肉麵 (Lat: 22.971, Lng: 120.288, Overall Score: 44.0)
#    - 睏飽 KUNBA BURGER 漢堡外帶店 (Lat: 22.9699, Lng: 120.292, Overall Score: 44.0)
#    - 麥當勞-台南歸仁餐廳 (Lat: 22.9669, Lng: 120.291, Overall Score: 44.0)
#    - 烤市院燒肉便當 (Lat: 22.968, Lng: 120.293, Overall Score: 44.0)
#    - 亦品屋手作廚房 (Lat: 22.9658, Lng: 120.293, Overall Score: 44.0)
#    - 歐爸餐桌 (Lat: 22.9693, Lng: 120.293, Overall Score: 44.0)
#    - 微微食作 WeiWei's Food【歸仁店】 (Lat: 22.9692, Lng: 120.292, Overall Score: 44.0)
#    - 大埔鐵板燒 台南歸仁店 (Lat: 22.9674, Lng: 120.29, Overall Score: 44.0)
#    - 黃家豆菜麵 中式早午餐 (Lat: 22.9663, Lng: 120.292, Overall Score: 44.0)
#    - 小口品嚐 (Lat: 22.9678, Lng: 120.296, Overall Score: 44.0)
#    - 戰鬥雞 油雞/醉雞 鮮燙蔬菜 歸仁中山店 (Lat: 22.9667, Lng: 120.293, Overall Score: 44.0)
#    - 歸仁豆乳雞 (Lat: 22.9702, Lng: 120.295, Overall Score: 44.0)
#    - 謝掌櫃虱目魚海鮮粥［安平總店］ (Lat: 22.9992, Lng: 120.162, Overall Score: 44.0)
#    - L'herbe 香草小餐酒 (Lat: 22.9921, Lng: 120.165, Overall Score: 44.0)
#    - 海牙館 (Lat: 22.9989, Lng: 120.163, Overall Score: 44.0)
#    - 阿財牛肉湯安平二店 (Lat: 22.9992, Lng: 120.164, Overall Score: 44.0)
#    - 阿美深海鮮魚湯 (Lat: 22.999, Lng: 120.163, Overall Score: 44.0)
#    - 歐若無國界餐桌OnO Table (Lat: 23.0011, Lng: 120.163, Overall Score: 44.0)
#    - 欣雅川菜館 (Lat: 22.9905, Lng: 120.167, Overall Score: 44.0)
#    - 本Hon鐵板燒-台南店 (Lat: 22.9915, Lng: 120.165, Overall Score: 44.0)
#    - 丹丹漢堡 安平店 (Lat: 22.9934, Lng: 120.164, Overall Score: 44.0)
#    - 小木積餐飲屋 (Lat: 22.9992, Lng: 120.167, Overall Score: 44.0)
#    - 品鮮炒飯 (Lat: 22.9904, Lng: 120.168, Overall Score: 44.0)
#    - 麥當勞-台南民族店 (Lat: 22.9947, Lng: 120.209, Overall Score: 44.0)
#    - 毛丼 丼飯專門店 (Lat: 22.9888, Lng: 120.215, Overall Score: 44.0)
#    - 元味屋和風洋食 (Lat: 22.9953, Lng: 120.215, Overall Score: 44.0)
#    - 鬥牛士二鍋中山店 (Lat: 22.9956, Lng: 120.21, Overall Score: 44.0)
#    - 阿香牛肉麵 (Lat: 23.0007, Lng: 120.198, Overall Score: 44.0)
#    - 鄉村柴火雞 (Lat: 22.995, Lng: 120.197, Overall Score: 44.0)
#    - Funkoo Bar - Mexican Cuisine & Bar (Lat: 22.9979, Lng: 120.198, Overall Score: 44.0)
#    - 湖仔清粥小菜 (Lat: 22.9987, Lng: 120.196, Overall Score: 44.0)
#    - 串亦燒-海安店 (Lat: 22.9941, Lng: 120.196, Overall Score: 44.0)
#    - 保安路媽媽早餐車 (Lat: 22.9377, Lng: 120.245, Overall Score: 44.0)
#    - 高仔豆漿早點 (Lat: 22.938, Lng: 120.248, Overall Score: 44.0)
#    - 田厝傳統早餐(煎餃 蛋餅 燒餅 飯糰) (Lat: 22.9379, Lng: 120.248, Overall Score: 44.0)
#    - 美而美早餐店 (Lat: 22.938, Lng: 120.248, Overall Score: 44.0)
#    - 鮮味軒餐廳 (Lat: 23.0106, Lng: 120.197, Overall Score: 44.0)
#    - 和偉麵館 (Lat: 23.0123, Lng: 120.204, Overall Score: 44.0)
#    - 職人焼き鳥Yakitori (Lat: 23.0065, Lng: 120.199, Overall Score: 44.0)
#    - 見月坊蔬食 (Lat: 23.0124, Lng: 120.199, Overall Score: 44.0)
#    - 夯龍美虎（花園夜市店） (Lat: 23.0114, Lng: 120.2, Overall Score: 44.0)
#    - 台南 吾慢食堂。在地短居。 (Lat: 23.007, Lng: 120.202, Overall Score: 44.0)
#    - 彩虹日本料理 - 和緯店 (Lat: 23.0101, Lng: 120.195, Overall Score: 44.0)
#    - 伊甸風味館 (Lat: 23.0096, Lng: 120.194, Overall Score: 44.0)
#    - 北安牛排 (Lat: 23.0077, Lng: 120.203, Overall Score: 44.0)
#    - 小北素食菜粽 (Lat: 23.009, Lng: 120.205, Overall Score: 44.0)
#    - 美而美早餐店 (Lat: 23.016, Lng: 120.199, Overall Score: 44.0)
#    - 嘉義楊氏美食鴨肉油飯 (Lat: 23.0114, Lng: 120.2, Overall Score: 44.0)
#    - 牛脾氣牛肉麵 (Lat: 23.0145, Lng: 120.194, Overall Score: 44.0)
#    - 米約廚房 Mi Yueh Kitchen(無接待七歲以下兒童） (Lat: 23.0003, Lng: 120.154, Overall Score: 44.0)
#    - 弄 Relationship (Lat: 23.0026, Lng: 120.16, Overall Score: 44.0)
#    - 韓樂亭 (Lat: 23.0001, Lng: 120.153, Overall Score: 44.0)
#    - 炸雞洋行 (Lat: 23.0004, Lng: 120.154, Overall Score: 44.0)
#    - 金魚京鍋燒意麵 (Lat: 23.0001, Lng: 120.154, Overall Score: 44.0)
#    - 養蚵世家 (Lat: 23.0, Lng: 120.154, Overall Score: 44.0)
#    - 廟邊海產 (Lat: 22.9998, Lng: 120.161, Overall Score: 44.0)
#    - Chou賀呷 (Lat: 22.9991, Lng: 120.161, Overall Score: 44.0)
#    - 彩虹屋早餐廣場 (Lat: 23.0028, Lng: 120.161, Overall Score: 44.0)
#    - 食味三千｜安平美食｜義大利麵｜燉飯｜鹹派 (Lat: 23.0036, Lng: 120.16, Overall Score: 44.0)
#    - 豪早GaoZa‧Brunch 早午餐 (Lat: 23.0592, Lng: 120.231, Overall Score: 44.0)
#    - 阿梅法國麵包 khương mai bánh mì (Lat: 23.0631, Lng: 120.229, Overall Score: 44.0)
#    - 拉亞漢堡 台南長和 (Lat: 23.0624, Lng: 120.229, Overall Score: 44.0)
#    - 台南轉角餐廳 (Lat: 22.9953, Lng: 120.221, Overall Score: 38.0)
#    - 凱吉思 (Lat: 22.9945, Lng: 120.214, Overall Score: 44.0)
#    - 遠東CAFÉ (Lat: 22.9964, Lng: 120.215, Overall Score: 44.0)
#    - 艾克斯義式餐酒館 (Lat: 22.995, Lng: 120.221, Overall Score: 38.0)
#    - is義式餐廳 (Lat: 22.9958, Lng: 120.221, Overall Score: 44.0)
#    - Lobby Lounge 大廳茶軒-台南遠東香格里拉 (Lat: 22.9966, Lng: 120.214, Overall Score: 44.0)
#    - 義式屋古拉爵 台南遠百成功店 (Lat: 22.9963, Lng: 120.214, Overall Score: 44.0)
#    - 成大光復餐廳 (Lat: 22.9993, Lng: 120.215, Overall Score: 44.0)
#    - Shanghai Pavilion 醉月樓 (Lat: 22.9964, Lng: 120.215, Overall Score: 38.0)
#    - Phở22河粉南洋小吃 (Lat: 22.9955, Lng: 120.221, Overall Score: 44.0)
#    - Nest de 后院泰式餐廳 (Lat: 22.9951, Lng: 120.221, Overall Score: 44.0)
#    - HALAL food 穆斯林的店 (Lat: 22.9954, Lng: 120.218, Overall Score: 44.0)
#    - 麥當勞-台南東區大學店 (Lat: 22.9959, Lng: 120.221, Overall Score: 44.0)
# ...
#
# Cluster 19:
#  - Size: 23 points
#  - Average Overall Score: 44.93
#  - Points:
#    - 瑞昇純手工土豆 (Lat: 22.9629, Lng: 120.324, Overall Score: 44.0)
#    - PIZZA ZOO 披炸屋 (Lat: 22.9611, Lng: 120.33, Overall Score: 44.0)
#    - 青風豬排飯 (Lat: 22.9616, Lng: 120.328, Overall Score: 44.0)
#    - 捲媽廚房 (Lat: 22.9643, Lng: 120.329, Overall Score: 44.0)
#    - 澳洲牛排關廟店 (Lat: 22.9593, Lng: 120.329, Overall Score: 44.0)
#    - 彌音素麵館 (Lat: 22.9632, Lng: 120.327, Overall Score: 44.0)
#    - 皇林餐飲 (Lat: 22.9604, Lng: 120.326, Overall Score: 44.0)
#    - 東方美漢堡店 (Lat: 22.9601, Lng: 120.326, Overall Score: 44.0)
#    - 金品食堂 (Lat: 22.9601, Lng: 120.328, Overall Score: 44.0)
#    - 乙勝拉麵，湯飯 (Lat: 22.9621, Lng: 120.33, Overall Score: 44.0)
#    - 百頁蕃薯糖 (Lat: 22.9611, Lng: 120.328, Overall Score: 44.0)
#    - 程家水餃 (Lat: 22.9589, Lng: 120.327, Overall Score: 44.0)
#    - 張錦味小吃店 (Lat: 22.96, Lng: 120.329, Overall Score: 44.0)
#    - 活力早餐吧 (Lat: 22.9632, Lng: 120.329, Overall Score: 44.0)
#    - 六巷道 (Lat: 22.9605, Lng: 120.33, Overall Score: 44.0)
#    - 韓星炸雞-關廟加盟店 (Lat: 22.9618, Lng: 120.326, Overall Score: 44.0)
#    - 23麵屋 (Lat: 22.9618, Lng: 120.325, Overall Score: 44.0)
#    - 板塊牛排關廟店 (Lat: 22.9611, Lng: 120.327, Overall Score: 44.0)
#    - 關廟廟口阿財香腸 (Lat: 22.9618, Lng: 120.326, Overall Score: 44.0)
#    - 關廟山西宮 (Lat: 22.9617, Lng: 120.325, Overall Score: 100.0)
#    - 玉山大旅社 (Lat: 22.9574, Lng: 120.328, Overall Score: 17.6)
#    - 靚屋 (Lat: 22.958, Lng: 120.329, Overall Score: 62.8)
#    - 山福旅社 (Lat: 22.9629, Lng: 120.327, Overall Score: 17.0)
#
# Cluster 38:
#  - Size: 21 points
#  - Average Overall Score: 49.76
#  - Points:
#    - 台南土城 宏蕎嫩骨鍋燒意麵 (Lat: 23.0658, Lng: 120.131, Overall Score: 44.0)
#    - 品多牛排小火鍋 (Lat: 23.0633, Lng: 120.13, Overall Score: 44.0)
#    - 龜鹿仙圓融園 (Lat: 23.066, Lng: 120.132, Overall Score: 44.0)
#    - 美琪餐飲 (Lat: 23.0668, Lng: 120.128, Overall Score: 44.0)
#    - 阿力香雞排（土城店） (Lat: 23.0659, Lng: 120.128, Overall Score: 44.0)
#    - 569餐飲屋 (Lat: 23.0619, Lng: 120.13, Overall Score: 44.0)
#    - 呷好味現宰溫體牛肉湯 (Lat: 23.0633, Lng: 120.129, Overall Score: 44.0)
#    - 【崇義素食】手工現做早餐 (Lat: 23.0641, Lng: 120.132, Overall Score: 44.0)
#    - 祥-豆乳雞翅（原 國宅夜市 總店） (Lat: 23.067, Lng: 120.128, Overall Score: 44.0)
#    - 新味香小吃店 (Lat: 23.063, Lng: 120.131, Overall Score: 44.0)
#    - 聖母廟古早味大腸包小 (Lat: 23.0639, Lng: 120.129, Overall Score: 44.0)
#    - 上海香酥雞 (Lat: 23.0639, Lng: 120.129, Overall Score: 44.0)
#    - 靜香緣素食 (Lat: 23.0636, Lng: 120.129, Overall Score: 44.0)
#    - 膳廚工坊 (Lat: 23.063, Lng: 120.129, Overall Score: 44.0)
#    - 津津港式快餐店 (Lat: 23.0622, Lng: 120.13, Overall Score: 44.0)
#    - 台南土城阿瑞餐廳 (Lat: 23.0693, Lng: 120.134, Overall Score: 44.0)
#    - 168炸雞專賣店 (Lat: 23.0628, Lng: 120.13, Overall Score: 44.0)
#    - 芋圓又紫//鍋燒意麵.冰品.小火鍋// (Lat: 23.0629, Lng: 120.131, Overall Score: 44.0)
#    - 臺南正統鹿耳門聖母廟 (Lat: 23.068, Lng: 120.127, Overall Score: 100.0)
#    - 城西防風林 (Lat: 23.0585, Lng: 120.136, Overall Score: 100.0)
#    - 回家旅行 (Lat: 23.0642, Lng: 120.131, Overall Score: 52.9)
#
# Cluster 17:
#  - Size: 19 points
#  - Average Overall Score: 52.84
#  - Points:
#    - 小邱小吃(邱家料理） (Lat: 23.214, Lng: 120.095, Overall Score: 44.0)
#    - A3日本料理 (Lat: 23.2115, Lng: 120.088, Overall Score: 44.0)
#    - 李聖宮-鹹酥雞 (Lat: 23.2165, Lng: 120.094, Overall Score: 44.0)
#    - 馬沙溝吳家蚵嗲 (Lat: 23.2168, Lng: 120.094, Overall Score: 44.0)
#    - 九叔公餐廳 將軍漁港海景宴會廳（海鮮蒸籠塔） (Lat: 23.2116, Lng: 120.088, Overall Score: 44.0)
#    - 馬沙溝小吃 (Lat: 23.2114, Lng: 120.088, Overall Score: 44.0)
#    - 海商海鮮餐廳 (Lat: 23.2107, Lng: 120.085, Overall Score: 44.0)
#    - 西濱商圈海巢生活空間 (Lat: 23.2116, Lng: 120.088, Overall Score: 44.0)
#    - 優哆食堂將軍漁港店 (Lat: 23.2116, Lng: 120.088, Overall Score: 44.0)
#    - 藏鮮家 (Lat: 23.2116, Lng: 120.088, Overall Score: 44.0)
#    - 葉媽魚嶺 (A3-6) (Lat: 23.2114, Lng: 120.089, Overall Score: 44.0)
#    - 阿玲小舖 (Lat: 23.2119, Lng: 120.088, Overall Score: 44.0)
#    - 將軍漁港-幸福天團 (Lat: 23.2114, Lng: 120.088, Overall Score: 44.0)
#    - 馬沙溝濱海遊憩區 MASHAGOU COASTAL RECREATION AREA (Lat: 23.2175, Lng: 120.084, Overall Score: 44.0)
#    - AMIS海邊坐坐覓食 (Lat: 23.2344, Lng: 120.098, Overall Score: 44.0)
#    - 港式九龍鹽酥雞 (Lat: 23.2336, Lng: 120.097, Overall Score: 44.0)
#    - 將軍觀光漁港 (Lat: 23.2116, Lng: 120.088, Overall Score: 100.0)
#    - 馬沙溝濱海遊樂區 (Lat: 23.2166, Lng: 120.084, Overall Score: 100.0)
#    - 蘆竹溝漁港 (Lat: 23.2345, Lng: 120.096, Overall Score: 100.0)
#
# Cluster 27:
#  - Size: 18 points
#  - Average Overall Score: 63.48
#  - Points:
#    - 詔安麵飯店 (Lat: 23.3934, Lng: 120.412, Overall Score: 44.0)
#    - 小當家麵食館 (Lat: 23.379, Lng: 120.417, Overall Score: 44.0)
#    - 玉豐早餐店 (Lat: 23.3782, Lng: 120.417, Overall Score: 44.0)
#    - 珍禾駕薑母鴨&臭薯條複合式炸物 (Lat: 23.3784, Lng: 120.417, Overall Score: 44.0)
#    - 蓮花產業文化資訊館 (Lat: 23.381, Lng: 120.417, Overall Score: 100.0)
#    - 小南海‧普陀寺 (Lat: 23.3904, Lng: 120.394, Overall Score: 100.0)
#    - 蓮花公園 (Lat: 23.3869, Lng: 120.414, Overall Score: 100.0)
#    - 林初埤木棉花道 (Lat: 23.3781, Lng: 120.41, Overall Score: 100.0)
#    - 土溝農村美術館 (Lat: 23.3743, Lng: 120.388, Overall Score: 100.0)
#    - 富國旅社 (Lat: 23.3504, Lng: 120.414, Overall Score: 15.5)
#    - 蓮鄉小筑 (Lat: 23.3551, Lng: 120.412, Overall Score: 55.0)
#    - 長奕雅築 (Lat: 23.3674, Lng: 120.403, Overall Score: 56.5)
#    - 三叔公的家 (Lat: 23.371, Lng: 120.412, Overall Score: 65.8)
#    - 鴻海大旅社 (Lat: 23.3495, Lng: 120.415, Overall Score: 18.8)
#    - 小南海藍花瑩庭園咖啡民宿 (Lat: 23.3834, Lng: 120.391, Overall Score: 75.4)
#    - 毓軒園民宿 (Lat: 23.3501, Lng: 120.416, Overall Score: 59.2)
#    - 蓮鄉雅築 (Lat: 23.3558, Lng: 120.413, Overall Score: 55.0)
#    - 白河院 (Lat: 23.3623, Lng: 120.408, Overall Score: 65.5)
#
# Cluster 24:
#  - Size: 14 points
#  - Average Overall Score: 46.62
#  - Points:
#    - 草原餐廳 (Lat: 23.1362, Lng: 120.427, Overall Score: 44.0)
#    - 田媽媽草香餐坊 (Lat: 23.1362, Lng: 120.427, Overall Score: 44.0)
#    - 茂興土雞城 (Lat: 23.1392, Lng: 120.433, Overall Score: 44.0)
#    - 走馬瀨農場｜草原餐廳 (Lat: 23.1362, Lng: 120.427, Overall Score: 44.0)
#    - 走馬瀨-星光世界-紅寶石冰店 (Lat: 23.1364, Lng: 120.427, Overall Score: 44.0)
#    - 祕密雞地國雄烤雞 (Lat: 23.1387, Lng: 120.434, Overall Score: 44.0)
#    - 走馬瀨農場｜蘭花會館｜蝴蝶餐廳 (Lat: 23.1364, Lng: 120.426, Overall Score: 44.0)
#    - 安仔甕缸雞 (Lat: 23.1378, Lng: 120.435, Overall Score: 44.0)
#    - 青町日式家庭料理 (Lat: 23.1389, Lng: 120.437, Overall Score: 44.0)
#    - 走馬瀨農場 (Lat: 23.1372, Lng: 120.43, Overall Score: 100.0)
#    - 台南市農會走馬瀨農場歐式旅館 (Lat: 23.1369, Lng: 120.43, Overall Score: 26.0)
#    - 556吉荷民宿 (Lat: 23.1498, Lng: 120.417, Overall Score: 63.7)
#    - 臺南市農會走馬瀨農場渡假木屋 (Lat: 23.1372, Lng: 120.43, Overall Score: 23.9)
#    - 走馬瀨農場蘭花會館 (Lat: 23.1372, Lng: 120.43, Overall Score: 43.099999999999994)
#
# Cluster 25:
#  - Size: 13 points
#  - Average Overall Score: 56.70
#  - Points:
#    - 黑山頂跑山雞 (Lat: 23.0645, Lng: 120.385, Overall Score: 44.0)
#    - 化石館桶仔雞小炒 (Lat: 23.0638, Lng: 120.388, Overall Score: 44.0)
#    - 化食館烤雞 (Lat: 23.0641, Lng: 120.387, Overall Score: 44.0)
#    - 悶燒雞 (Lat: 23.0557, Lng: 120.404, Overall Score: 44.0)
#    - ㄚ嘉鋼管雞 (Lat: 23.0543, Lng: 120.403, Overall Score: 44.0)
#    - 平埔族美食 (Lat: 23.0559, Lng: 120.401, Overall Score: 44.0)
#    - 椰子林美食餐廳 (Lat: 23.0535, Lng: 120.406, Overall Score: 44.0)
#    - 化石館桶仔雞熱炒 (Lat: 23.0595, Lng: 120.406, Overall Score: 44.0)
#    - 菜寮化石館 (Lat: 23.0643, Lng: 120.389, Overall Score: 100.0)
#    - 噶瑪噶居寺 (Lat: 23.0532, Lng: 120.399, Overall Score: 100.0)
#    - 晨曦山莊 (Lat: 23.068, Lng: 120.377, Overall Score: 65.8)
#    - 左鎮農場民宿 (Lat: 23.068, Lng: 120.377, Overall Score: 54.4)
#    - 晨曦紅瓦厝 (Lat: 23.0683, Lng: 120.376, Overall Score: 64.9)
#
# Cluster 34:
#  - Size: 9 points
#  - Average Overall Score: 56.44
#  - Points:
#    - 山海珍宴席團 (Lat: 22.9665, Lng: 120.36, Overall Score: 44.0)
#    - 阿輝土雞城 (Lat: 22.9693, Lng: 120.355, Overall Score: 44.0)
#    - 采竹香食堂 (Lat: 22.9664, Lng: 120.36, Overall Score: 44.0)
#    - 青龍山公園土雞城 (Lat: 22.9689, Lng: 120.355, Overall Score: 44.0)
#    - 黃永順 (Lat: 22.9669, Lng: 120.359, Overall Score: 44.0)
#    - 龍泉岩土雞莊 (Lat: 22.9684, Lng: 120.354, Overall Score: 44.0)
#    - 新龍莊土雞城 (Lat: 22.9689, Lng: 120.353, Overall Score: 44.0)
#    - 龍崎竹炭故事館 (Lat: 22.9646, Lng: 120.36, Overall Score: 100.0)
#    - 虎形山公園 (Lat: 22.9645, Lng: 120.36, Overall Score: 100.0)
#
# Cluster 2:
#  - Size: 9 points
#  - Average Overall Score: 50.22
#  - Points:
#    - 二層坪梅子雞 (Lat: 23.1812, Lng: 120.559, Overall Score: 44.0)
#    - 妙元素食坊 (Lat: 23.18, Lng: 120.561, Overall Score: 44.0)
#    - 大眾餐飲 (Lat: 23.1843, Lng: 120.56, Overall Score: 44.0)
#    - 天香園梅仔雞餐廳 (Lat: 23.1813, Lng: 120.559, Overall Score: 44.0)
#    - 二層坪梅子雞 (Lat: 23.1812, Lng: 120.559, Overall Score: 44.0)
#    - 文川梅子雞城 (Lat: 23.1814, Lng: 120.559, Overall Score: 44.0)
#    - 梅嶺野店食堂 (Lat: 23.1822, Lng: 120.559, Overall Score: 44.0)
#    - 賴媽媽手工饅頭 (Lat: 23.1836, Lng: 120.571, Overall Score: 44.0)
#    - 梅嶺 (Lat: 23.1801, Lng: 120.566, Overall Score: 100.0)
#
# Cluster 21:
#  - Size: 9 points
#  - Average Overall Score: 48.89
#  - Points:
#    - 琳鳳營卡拉OK (Lat: 23.2406, Lng: 120.313, Overall Score: 44.0)
#    - 金園商行 (Lat: 23.2436, Lng: 120.319, Overall Score: 44.0)
#    - 觀賞雞樂園 (Lat: 23.2399, Lng: 120.313, Overall Score: 44.0)
#    - 炊牛牛肉湯 (Lat: 23.2515, Lng: 120.313, Overall Score: 44.0)
#    - 弘爺漢堡名捷店 (Lat: 23.25, Lng: 120.311, Overall Score: 44.0)
#    - 台南六甲-九品蓮花生態教育園區 (Lat: 23.245, Lng: 120.317, Overall Score: 44.0)
#    - 蓮花世界 (Lat: 23.2451, Lng: 120.318, Overall Score: 100.0)
#    - 布拉格汽車旅館 (Lat: 23.2542, Lng: 120.309, Overall Score: 32.6)
#    - 硯月精品汽車旅館 (Lat: 23.2532, Lng: 120.311, Overall Score: 43.4)
#
# Cluster 18:
#  - Size: 9 points
#  - Average Overall Score: 55.42
#  - Points:
#    - 長泰隆 (Lat: 23.0266, Lng: 120.335, Overall Score: 44.0)
#    - 新化林家園藝 (Lat: 23.0243, Lng: 120.337, Overall Score: 44.0)
#    - 高雅小吃店 (Lat: 23.0261, Lng: 120.335, Overall Score: 44.0)
#    - 虎頭埤阿嬤烤地瓜 (Lat: 23.0275, Lng: 120.336, Overall Score: 44.0)
#    - 正宗北京風味蔥油餅 (Lat: 23.0269, Lng: 120.336, Overall Score: 44.0)
#    - 虎頭埤風景區 (Lat: 23.0279, Lng: 120.341, Overall Score: 100.0)
#    - 綠的抱抱 (Lat: 23.0375, Lng: 120.345, Overall Score: 55.6)
#    - 台南.山居166 (Lat: 23.0363, Lng: 120.346, Overall Score: 59.2)
#    - 山莊別野 (Lat: 23.0355, Lng: 120.355, Overall Score: 64.0)
#
# Cluster 22:
#  - Size: 7 points
#  - Average Overall Score: 52.69
#  - Points:
#    - 桂華園 (Lat: 23.2645, Lng: 120.394, Overall Score: 44.0)
#    - 尖山埤宴會廳 (Lat: 23.2646, Lng: 120.394, Overall Score: 44.0)
#    - 台灣杉大腸蔥味香腸 (Lat: 23.2652, Lng: 120.388, Overall Score: 44.0)
#    - 遠翠樓 - 柳營尖山埤渡假村 (Lat: 23.2638, Lng: 120.39, Overall Score: 44.0)
#    - 柳營尖山埤渡假村 (Lat: 23.2642, Lng: 120.394, Overall Score: 44.0)
#    - 尖山埤水庫（江南渡假村） (Lat: 23.2611, Lng: 120.39, Overall Score: 100.0)
#    - 柳營尖山埤渡假村 (Lat: 23.2665, Lng: 120.393, Overall Score: 48.8)
#
# Cluster 32:
#  - Size: 7 points
#  - Average Overall Score: 49.11
#  - Points:
#    - 早點176 (Lat: 23.1749, Lng: 120.207, Overall Score: 44.0)
#    - 永昌美食坊 (Lat: 23.1748, Lng: 120.207, Overall Score: 44.0)
#    - 子龍早餐店 (Lat: 23.1752, Lng: 120.208, Overall Score: 44.0)
#    - 思豪外省麵 (Lat: 23.175, Lng: 120.206, Overall Score: 44.0)
#    - 晶帥西點麵包烘焙坊 (Lat: 23.1748, Lng: 120.206, Overall Score: 44.0)
#    - 柚樹黃昏休閒民宿 (Lat: 23.1991, Lng: 120.218, Overall Score: 56.2)
#    - 睫毛不翹的驢子 (Lat: 23.1896, Lng: 120.213, Overall Score: 67.6)
#
# Cluster 33:
#  - Size: 6 points
#  - Average Overall Score: 85.07
#  - Points:
#    - 阿美土雞城 (Lat: 23.0151, Lng: 120.415, Overall Score: 44.0)
#    - 台南市自然史博物館 (Lat: 23.0301, Lng: 120.424, Overall Score: 100.0)
#    - 草山月世界 (Lat: 22.9872, Lng: 120.424, Overall Score: 100.0)
#    - 岡林水管屋 (Lat: 23.009, Lng: 120.416, Overall Score: 100.0)
#    - 二寮觀日亭 (Lat: 22.9927, Lng: 120.41, Overall Score: 100.0)
#    - 想半天民宿 (Lat: 23.0063, Lng: 120.42, Overall Score: 66.4)
#
# Cluster 4:
#  - Size: 5 points
#  - Average Overall Score: 50.48
#  - Points:
#    - 龜丹六二溫泉山房 (Lat: 23.1289, Lng: 120.516, Overall Score: 38.0)
#    - 天喜悅溫泉會館 (Lat: 23.1331, Lng: 120.509, Overall Score: 30.5)
#    - 龜丹六二溫泉山房 (Lat: 23.1346, Lng: 120.496, Overall Score: 66.4)
#    - 龜丹休閒體驗農園 (Lat: 23.1332, Lng: 120.505, Overall Score: 61.0)
#    - 德恩農園 (Lat: 23.1334, Lng: 120.507, Overall Score: 56.5)
#
# Cluster 5:
#  - Size: 5 points
#  - Average Overall Score: 36.80
#  - Points:
#    - 高麗園銅盤烤肉 台南三井市場 (Lat: 22.9247, Lng: 120.288, Overall Score: 38.0)
#    - 韓國食堂 菜豚屋 台南三井店 (Lat: 22.9252, Lng: 120.288, Overall Score: 26.0)
#    - La Vida Lounge 宣 聚落－台南歸仁｜必吃輕食 網友推薦酒吧 網美網紅好評創意調酒 高CP值啤酒 首選早午餐 好吃下午茶 人氣咖啡 特色飲品價格 美食餐廳評價 熱門人氣餐酒館 約會聚會慶生包場 (Lat: 22.9278, Lng: 120.289, Overall Score: 38.0)
#    - Overtime 超時酒吧 (Lat: 22.928, Lng: 120.289, Overall Score: 44.0)
#    - 乾杯燒肉居酒屋 台南三井店 (Lat: 22.9244, Lng: 120.288, Overall Score: 38.0)
#
# Cluster 39:
#  - Size: 4 points
#  - Average Overall Score: 76.10
#  - Points:
#    - 御膳房 (Lat: 23.3216, Lng: 120.447, Overall Score: 44.0)
#    - 六重溪親水公園 (Lat: 23.3107, Lng: 120.461, Overall Score: 100.0)
#    - 台灣萬里長城 (Lat: 23.3196, Lng: 120.447, Overall Score: 100.0)
#    - 千霞園(特色民宿) (Lat: 23.3047, Lng: 120.475, Overall Score: 60.4)
#
# Cluster 40:
#  - Size: 4 points
#  - Average Overall Score: 44.00
#  - Points:
#    - 彙真麵館 (Lat: 23.0758, Lng: 120.324, Overall Score: 44.0)
#    - 早安山丘-新市潭頂店 (Lat: 23.0767, Lng: 120.322, Overall Score: 44.0)
#    - 潭頂早餐車 (Lat: 23.0767, Lng: 120.321, Overall Score: 44.0)
#    - 長利商店(早餐店) (Lat: 23.076, Lng: 120.323, Overall Score: 44.0)
#
# Cluster 10:
#  - Size: 4 points
#  - Average Overall Score: 56.38
#  - Points:
#    - 籃記豆花 (Lat: 23.3224, Lng: 120.403, Overall Score: 38.0)
#    - 向陽田園居民宿 (Lat: 23.3202, Lng: 120.418, Overall Score: 70.0)
#    - 董娘美食生活館 (Lat: 23.3147, Lng: 120.409, Overall Score: 51.4)
#    - 四季庭園 (Lat: 23.3221, Lng: 120.41, Overall Score: 66.1)
#
# Cluster 31:
#  - Size: 4 points
#  - Average Overall Score: 86.00
#  - Points:
#    - 保警食堂 (Lat: 23.3291, Lng: 120.374, Overall Score: 44.0)
#    - 台灣蘭花生物科技園區 (Lat: 23.3392, Lng: 120.378, Overall Score: 100.0)
#    - 烏樹林五分車 (Lat: 23.3362, Lng: 120.377, Overall Score: 100.0)
#    - 烏樹林休閒博物館 (Lat: 23.3289, Lng: 120.373, Overall Score: 100.0)
#
# Cluster 28:
#  - Size: 4 points
#  - Average Overall Score: 66.75
#  - Points:
#    - 果農之家 (Lat: 23.1996, Lng: 120.512, Overall Score: 44.0)
#    - 果農之家 (Lat: 23.1996, Lng: 120.512, Overall Score: 100.0)
#    - 江家古厝 (Lat: 23.182, Lng: 120.516, Overall Score: 100.0)
#    - 趣淘漫旅 (Lat: 23.2031, Lng: 120.514, Overall Score: 23.0)
#
# Cluster 23:
#  - Size: 4 points
#  - Average Overall Score: 55.75
#  - Points:
#    - 碼頭餐廳 (Lat: 23.2386, Lng: 120.381, Overall Score: 44.0)
#    - 理想會客菜 (Lat: 23.2373, Lng: 120.373, Overall Score: 44.0)
#    - 南元休閒農場 (Lat: 23.2401, Lng: 120.379, Overall Score: 100.0)
#    - 南元休閒農場湖上渡假村 (Lat: 23.2404, Lng: 120.378, Overall Score: 35.0)
#
# Cluster 29:
#  - Size: 3 points
#  - Average Overall Score: 62.67
#  - Points:
#    - 忘憂谷 (Lat: 22.9779, Lng: 120.442, Overall Score: 44.0)
#    - 大峽谷優美山莊 (Lat: 22.9782, Lng: 120.441, Overall Score: 44.0)
#    - 草山月世界308高地 (Lat: 22.977, Lng: 120.443, Overall Score: 100.0)
#
# Cluster 35:
#  - Size: 3 points
#  - Average Overall Score: 81.33
#  - Points:
#    - 黑琵食堂餐廳 (Lat: 23.0827, Lng: 120.063, Overall Score: 44.0)
#    - 黑面琵鷺賞鳥區 (Lat: 23.0791, Lng: 120.053, Overall Score: 100.0)
#    - 黑面琵鷺生態展示館 (Lat: 23.0814, Lng: 120.063, Overall Score: 100.0)
#
# Cluster 37:
#  - Size: 3 points
#  - Average Overall Score: 62.67
#  - Points:
#    - 磅空子壹號古早味關廟乾麵 (Lat: 22.9289, Lng: 120.41, Overall Score: 44.0)
#    - 吉祥土雞城 (Lat: 22.9269, Lng: 120.41, Overall Score: 44.0)
#    - 牛埔泥岩水土教育園區 (Lat: 22.9276, Lng: 120.41, Overall Score: 100.0)
#
# Cluster 26:
#  - Size: 3 points
#  - Average Overall Score: 73.53
#  - Points:
#    - 王家燻羊肉 (Lat: 23.0059, Lng: 120.389, Overall Score: 44.0)
#    - 大坑休閒農場 (Lat: 23.007, Lng: 120.391, Overall Score: 100.0)
#    - 大坑休閒農場 (Lat: 23.0044, Lng: 120.394, Overall Score: 76.6)
#
# Cluster 41:
#  - Size: 3 points
#  - Average Overall Score: 68.53
#  - Points:
#    - 樹頂屋餐廳 (Lat: 23.2774, Lng: 120.208, Overall Score: 44.0)
#    - 頑皮世界野生動物園 (Lat: 23.281, Lng: 120.209, Overall Score: 100.0)
#    - 台灣詩路 (Lat: 23.2774, Lng: 120.228, Overall Score: 61.6)
#
# Cluster 42:
#  - Size: 3 points
#  - Average Overall Score: 63.03
#  - Points:
#    - 港香蘭綠色健康知識館 (Lat: 23.078, Lng: 120.292, Overall Score: 100.0)
#    - 新大南科大飯店 (Lat: 23.0799, Lng: 120.295, Overall Score: 31.099999999999998)
#    - 巧遇南科民宿 (Lat: 23.0766, Lng: 120.28, Overall Score: 58.0)
#
# Cluster 43:
#  - Size: 3 points
#  - Average Overall Score: 66.70
#  - Points:
#    - 康那香不織布創意王國 (Lat: 23.2, Lng: 120.131, Overall Score: 100.0)
#    - 春院子 (Lat: 23.2147, Lng: 120.134, Overall Score: 49.0)
#    - 嘉源民宿 (Lat: 23.1891, Lng: 120.134, Overall Score: 51.1)

# %%
# 行程安排: 一天玩一個cluster，該日的地點都在此cluster中，以df儲存行程資料、畫 map3 以檢視所挑選的地點分布的狀況。(地圖僅做檢查用 最後要拉掉)

"""挑選邏輯: 請參考以下與 mr.G 的對話

請聽好我的需求 幫我完成程式碼
我先說明一下我的geo_df 分別都有 id name	lat	lng	geometry info overall_score cluster source
範例資料:
name	lat	lng	geometry	overall_score	source
6	和牛涮 台南中華西店	22.9935	120.187	POINT (120.18700 22.99350)	午餐,晚餐	44.0	food
42	小豪洲沙茶爐中正總店	22.9932	120.200	POINT (120.20000 22.99320)	午餐,晚餐	44.0	food
63	輕井澤鍋物 台南店	22.9869	120.186	POINT (120.18600 22.98690)	午餐,晚餐	44.0	food
73	阿裕牛肉涮涮鍋一崑崙店	22.9404	120.261	POINT (120.26100 22.94040)	午餐,晚餐	38.0	food
75	是吉祥精緻火鍋館	22.9780	120.186	POINT (120.18600 22.97800)	午餐,晚餐	44.0	food
...	...	...	...	...	...	...
7 助哥親民民宿	22.9970	120.195	POINT (120.19500 22.99700)	Nan	55.1	hotel
31 開山芳庭	22.9908	120.207	POINT (120.20700 22.99080)	Nan	26.0	hotel
63 安平安逸	23.0024	120.158	POINT (120.15800 23.00240)	Nan	44.0	hotel
...	...	...	...	...	...	...
88 助哥親民民宿	22.9970	120.195	POINT (120.19500 22.99700)	Nan	55.1	viewpoint

我給你的pref的天數假設是3天，那麼 第一天的行程會在最大的cluster，第二天在第二大的cluster...以此類推。
每一天的地點都在同一個cluster中挑選
請你幫我用greedy的方式在個別cluster中安排每天行程  viewpoint1 -> food1 -> viewpoint2 -> viewpoint3 -> food3 -> hotel 
挑法詳細說明如下

viewpoint1  :  挑選source=veiwpoint 中 ， overall_score 欄位值最大的那一個。需印出此起始點的經緯度。
food1 : source=food 中，  篩選出距離viewpoint1  500公尺內的地點(若無則每次加大100公尺直到有至少10筆資料。從篩選出的資料中，挑選 overall_score 欄位值最大的那一個。需印出與上一個地點的距離。
viewpoint2: source=veiwpoint 中， 篩選出距離food1 600公尺內的地點(若無則每次加大200公尺直到有至少2筆資料。從篩選出的資料中，挑選 overall_score 欄位值最大的那一個。需印出與上一個地點的距離。不得重複挑選。
viewpoint3: source=veiwpoint  中，篩選出距離viewpoint2 700公尺內的地點(若無則每次加大300公尺直到有至少2筆資料。從篩選出的資料中，挑選 overall_score 欄位值最大的那一個。需印出與上一個地點的距離。不得重複挑選。
food2 : source=food  中，篩選出距離viewpoint3 500公尺內的地點(若無則每次加大100公尺直到有至少10筆資料。從篩選出的資料中，挑選 overall_score 欄位值最大的那一個。需印出與上一個地點的距離。
hotel: source=hotel  中，篩選出距離viewpoint3 600公尺內的地點(若無則每次加大300公尺直到有至少15筆資料。從篩選出的資料中，挑選 overall_score 欄位值最大的那一個。需印出與上一個地點的距離。

以上的資訊要列印成每天的行程表，並且將每天的行程地點標示在地圖 "map_selected"上
每一天就用不同顏色的座標標示，並且要在座標放入地點的詳細資訊 (詳細資訊就幫我從geo_df 抓各欄位內容)

"""


import pandas as pd
import folium
from folium.plugins import MarkerCluster

# 创建地图
m3 = folium.Map(location=[geo_df['lat'].mean(), geo_df['lng'].mean()], zoom_start=12)

# 设置不同的颜色，用于不同天的行程
colors = ['red', 'blue', 'green']

# 初始化每天的行程
daily_itineraries = []

# 初始化一个 DataFrame 以存储选定的行程
selected_itinerary_df = pd.DataFrame(columns=['day', 'step', 'source', 'name', 'lat', 'lng', 'distance']) # distance (跟上一步的距離)

# 根据聚类拆分数据
cluster_sizes = geo_df['cluster'].value_counts()
largest_clusters = cluster_sizes.nlargest(pref['dates']).index

# 遍历每个聚类
for day, cluster_id in enumerate(largest_clusters):
    cluster_color = colors[day % len(colors)]
    cluster_data = geo_df[geo_df['cluster'] == cluster_id]
    
    # 存储每天的行程点和信息
    daily_points = []
    daily_info = []
    step = 1
    
    # 挑選viewpoint1
    viewpoint1 = cluster_data[cluster_data['source'] == 'viewpoint'].nlargest(1, 'overall_score').iloc[0]
    daily_points.append(viewpoint1)
    daily_info.append(f"Source: {viewpoint1['source']}, Distance: 0 meters")
    
    # 挑選food1
    distance_threshold = 500
    food1 = cluster_data[(cluster_data['source'] == 'food') &
                         (cluster_data.geometry.distance(viewpoint1.geometry)*111.32*1000 <= distance_threshold)]
    while len(food1) < 1:
        distance_threshold += 100
        food1 = cluster_data[(cluster_data['source'] == 'food') &
                             (cluster_data.geometry.distance(viewpoint1.geometry)*111.32*1000 <= distance_threshold)]
    
    food1 = food1.nlargest(1, 'overall_score').iloc[0]
    daily_points.append(food1)
    distance_to_previous = food1.geometry.distance(viewpoint1.geometry)*111.32*1000
    daily_info.append(f"Source: {food1['source']}, Distance: {distance_to_previous:.2f} meters")
    
    # 挑選viewpoint2
    distance_threshold = 600
    viewpoint2 = cluster_data[(cluster_data['source'] == 'viewpoint') &
                              (cluster_data.geometry.distance(food1.geometry)*111.32*1000 <= distance_threshold) &
                              (cluster_data['id'] != viewpoint1['id'])].nlargest(1, 'overall_score').iloc[0]
    daily_points.append(viewpoint2)
    distance_to_previous = viewpoint2.geometry.distance(food1.geometry)*111.32*1000
    daily_info.append(f"Source: {viewpoint2['source']}, Distance: {distance_to_previous:.2f} meters")
    
    # 挑選viewpoint3
    distance_threshold = 700
    viewpoint3 = cluster_data[(cluster_data['source'] == 'viewpoint') &
                              (cluster_data.geometry.distance(viewpoint2.geometry)*111.32*1000 <= distance_threshold) &
                              (cluster_data['id'] != viewpoint1['id']) &
                              (cluster_data['id'] != viewpoint2['id'])].nlargest(1, 'overall_score').iloc[0]
    daily_points.append(viewpoint3)
    distance_to_previous = viewpoint3.geometry.distance(viewpoint2.geometry)*111.32*1000
    daily_info.append(f"Source: {viewpoint3['source']}, Distance: {distance_to_previous:.2f} meters")
    
    # 挑選food2
    distance_threshold = 500
    food2 = cluster_data[(cluster_data['source'] == 'food') &
                         (cluster_data.geometry.distance(viewpoint3.geometry)*111.32*1000 <= distance_threshold) &
                         (cluster_data['id'] != food1['id'])].nlargest(1, 'overall_score').iloc[0]
    daily_points.append(food2)
    distance_to_previous = food2.geometry.distance(viewpoint3.geometry)*111.32*1000
    daily_info.append(f"Source: {food2['source']}, Distance: {distance_to_previous:.2f} meters")
    
    # 挑選hotel
    distance_threshold = 600
    hotel = cluster_data[(cluster_data['source'] == 'hotel') &
                         (cluster_data.geometry.distance(viewpoint3.geometry)*111.32*1000 <= distance_threshold)].nlargest(1, 'overall_score').iloc[0]
    daily_points.append(hotel)
    distance_to_previous = hotel.geometry.distance(viewpoint3.geometry)*111.32*1000
    daily_info.append(f"Source: {hotel['source']}, Distance: {distance_to_previous:.2f} meters")
    
    # 将每天的行程点存入每天的行程表中
    daily_itineraries.append((daily_points, daily_info))
    
    # 将每天的行程信息添加到 DataFrame
    for point, info in zip(daily_points, daily_info):
        selected_itinerary_df = pd.concat([selected_itinerary_df, pd.DataFrame([{'day': day + 1,
                                                              'name': point['name'],
                                                              'lat': point['lat'],
                                                              'lng': point['lng'],
                                                              'source': point['source'],
                                                              'distance': info.split(": ")[-1],
                                                              'step': step}])], ignore_index=True)

        step += 1
    
    # 在地图上标示每天的行程点
    marker_cluster = MarkerCluster().add_to(m3)
    for point, info in zip(daily_points, daily_info):
        folium.Marker(
            location=[point['lat'], point['lng']],
            popup=f"{point['name']} - {info}",
            icon=folium.Icon(color=cluster_color)
        ).add_to(marker_cluster)

# 保存地图为HTML文件 (或者 display)
m3.save("map3.html")
# display(m3)

# %%
# 輸出行程: 以 df 丟回去給 Lewis的API (或要在這邊轉好JSON也行)

# Output DataFrame:
selected_itinerary_df
# Out:
#    day step     source                name      lat      lng       distance
# 0    1    1  viewpoint               延平街古井  23.0009  120.162       0 meters
# 1    1    2       food  Suns' Great / 向光旅行  23.0010  120.164  222.92 meters
# 2    1    3  viewpoint              德商東興洋行  23.0018  120.159  563.68 meters
# 3    1    4  viewpoint               安平小砲台  22.9995  120.159  256.04 meters
# 4    1    5       food                陳家蚵捲  23.0004  120.162  348.66 meters
# 5    1    6      hotel              運河十六民宿  22.9990  120.163  448.75 meters
# 6    2    1  viewpoint         橋南老街（橋南街李宅）  23.3159  120.268       0 meters
# 7    2    2       food         廚心食意無刺虱目專賣店  23.3150  120.267  149.77 meters
# 8    2    3  viewpoint               鹽水八角樓  23.3200  120.267  556.60 meters
# 9    2    4  viewpoint                鹽水武廟  23.3238  120.266  437.42 meters
# 10   2    5       food                上好食堂  23.3199  120.268  487.91 meters
# 11   2    6      hotel           好生活整合國際旅宿  23.3223  120.271  581.11 meters
# 12   3    1  viewpoint                紅葉公園  23.3421  120.506       0 meters
# 13   3    2       food               竹茅土雞城  23.3410  120.502  461.81 meters
# 14   3    3  viewpoint                嶺頂公園  23.3381  120.504  392.16 meters
# 15   3    4  viewpoint                 好漢坡  23.3375  120.504   66.79 meters
# 16   3    5       food                菜頭飯麵  23.3361  120.504  155.85 meters
# 17   3    6      hotel                沐春民宿  23.3361  120.505  191.52 meters
